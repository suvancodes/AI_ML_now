# %% [markdown]
# # convert json to string

# %%
import pandas as pd
from io import StringIO as si

# Sample JSON string
data = '''
[
  {"id": 1, "name": "Ankit Roy", "age": 21, "department": "CSE", "cgpa": 8.5},
  {"id": 2, "name": "Sneha Das", "age": 20, "department": "ECE", "cgpa": 9.1},
  {"id": 3, "name": "Rahul Sen", "age": 22, "department": "ME", "cgpa": 7.8},
  {"id": 4, "name": "Priya Sharma", "age": 21, "department": "IT", "cgpa": 8.9}
]
'''
# Convert string to file-like object and read
df = pd.read_json(si(data))
print(df)
print(type(df))
# Out:
#    id          name  age department  cgpa
# 0   1     Ankit Roy   21        CSE   8.5
# 1   2     Sneha Das   20        ECE   9.1
# 2   3     Rahul Sen   22         ME   7.8
# 3   4  Priya Sharma   21         IT   8.9
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# # string to json

# %%
df.to_json()
# Out:
# '{"id":{"0":1,"1":2,"2":3,"3":4},"name":{"0":"Ankit Roy","1":"Sneha Das","2":"Rahul Sen","3":"Priya Sharma"},"age":{"0":21,"1":20,"2":22,"3":21},"department":{"0":"CSE","1":"ECE","2":"ME","3":"IT"},"cgpa":{"0":8.5,"1":9.1,"2":7.8,"3":8.9}}'

# %% [markdown]
# # using orintation

# %%
df.to_json(orient='records')
# Out:
# '[{"id":1,"name":"Ankit Roy","age":21,"department":"CSE","cgpa":8.5},{"id":2,"name":"Sneha Das","age":20,"department":"ECE","cgpa":9.1},{"id":3,"name":"Rahul Sen","age":22,"department":"ME","cgpa":7.8},{"id":4,"name":"Priya Sharma","age":21,"department":"IT","cgpa":8.9}]'

# %%
# it is defult
df.to_json(orient='index')
# Out:
# '{"0":{"id":1,"name":"Ankit Roy","age":21,"department":"CSE","cgpa":8.5},"1":{"id":2,"name":"Sneha Das","age":20,"department":"ECE","cgpa":9.1},"2":{"id":3,"name":"Rahul Sen","age":22,"department":"ME","cgpa":7.8},"3":{"id":4,"name":"Priya Sharma","age":21,"department":"IT","cgpa":8.9}}'

# %% [markdown]
# # read for a link

# %% [markdown]
# # read a json using url

# %%
import pandas as pd

d = pd.read_json('https://jsonplaceholder.typicode.com/users')
d.head()
# Out:
#    id              name   username                      email  \
# 0   1     Leanne Graham       Bret          Sincere@april.biz
# 1   2      Ervin Howell  Antonette          Shanna@melissa.tv
# 2   3  Clementine Bauch   Samantha         Nathan@yesenia.net
# 3   4  Patricia Lebsack   Karianne  Julianne.OConner@kory.org
# 4   5  Chelsey Dietrich     Kamren   Lucio_Hettinger@annie.ca
#
#                                              address                  phone  \
# 0  {'street': 'Kulas Light', 'suite': 'Apt. 556',...  1-770-736-8031 x56442
# 1  {'street': 'Victor Plains', 'suite': 'Suite 87...    010-692-6593 x09125
# 2  {'street': 'Douglas Extension', 'suite': 'Suit...         1-463-123-4447
# 3  {'street': 'Hoeger Mall', 'suite': 'Apt. 692',...      493-170-9623 x156
# 4  {'street': 'Skiles Walks', 'suite': 'Suite 351...          (254)954-1289
#
#          website                                            company
# ...

# %% [markdown]
# # read html file

# %%
pip install lxml
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 4.0 MB/s  0:00:01 eta 0:00:01
# ...
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
url = "https://www.fdic.gov/resources/resolutions/bank-failures/failed-bank-list/"
tables = pd.read_html(url)

# Print the number of tables and show the first one
print(f"Total tables found: {len(tables)}")
tables[0].head()
# Out:
# Total tables found: 1
#                                             Bank Name                City  \
# 0                   Metropolitan Capital Bank & Trust             Chicago
# 1                        The Santa Anna National Bank          Santa Anna
# 2                                Pulaski Savings Bank             Chicago
# 3                  The First National Bank of Lindsay             Lindsay
# 4               Republic First Bank dba Republic Bank        Philadelphia
# 5                                       Citizens Bank            Sac City
# 6                            Heartland Tri-State Bank             Elkhart
# 7                                 First Republic Bank       San Francisco
# 8                                      Signature Bank            New York
# 9                                 Silicon Valley Bank         Santa Clara
# 10                                  Almena State Bank              Almena
# ...

# %%
pip install pandas openpyxl
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [openpyxl]1/2 [openpyxl]
# ...
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # excel file

# %% [markdown]
# ## make an excel file and read it

# %%
import pandas as pd
data = {
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [24, 27, 22],
    'City': ['New York', 'San Francisco', 'Chicago']
}
df1 = pd.DataFrame(data)
df1.to_excel('my_data.xlsx', index=False)
# read it 
df1 = pd.read_excel('my_data.xlsx')
df1
# Out:
#       Name  Age           City
# 0    Alice   24       New York
# 1      Bob   27  San Francisco
# 2  Charlie   22        Chicago

# %% [markdown]
# ## convert this in a pickle file

# %%
df1.to_pickle('df1')

# %% [markdown]
# ## read this file

# %%
pd.read_pickle('df1')
# Out:
#       Name  Age           City
# 0    Alice   24       New York
# 1      Bob   27  San Francisco
# 2  Charlie   22        Chicago

# %%
data = [
  {
    "id": 1,
    "name": "Leanne Graham",
    "username": "Bret",
    "email": "Sincere@april.biz"
  },
  {
    "id": 2,
    "name": "Ervin Howell",
    "username": "Antonette",
    "email": "Shanna@melissa.tv"
  }
]
d = pd.DataFrame(data)
d
# Out:
#    id           name   username              email
# 0   1  Leanne Graham       Bret  Sincere@april.biz
# 1   2   Ervin Howell  Antonette  Shanna@melissa.tv
