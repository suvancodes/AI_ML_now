# %% [markdown]
# #  data visualisation with Seaborn

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns

# %% [markdown]
# ## basics ploting with seaborn

# %% [markdown]
# ### get data form seaborn

# %%
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# ### create a scatter plot

# %%
import matplotlib.pyplot as plt
sns.scatterplot(x='total_bill',y='tip',data=tips)
plt.title('subho')
plt.show()

# %% [markdown]
# ### line plot

# %%
sns.lineplot(x ='size',y='total_bill',data=tips)
plt.title('line plot')
# Out:
# Text(0.5, 1.0, 'line plot')

# %% [markdown]
# ## catagorical plot

# %% [markdown]
# ### bar plot

# %%
sns.barplot(x='day',y='total_bill',data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ### box plot

# %%
sns.boxplot(x='day',y='total_bill',data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ### violinplot

# %%
sns.violinplot(x='day',y='total_bill',data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ### histogram

# %%
sns.histplot(tips['total_bill'],bins=10,kde=True)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %% [markdown]
# ### kde

# %%
sns.kdeplot(tips['total_bill'],fill= True)
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %% [markdown]
# ### pairplot

# %%
sns.pairplot(tips)

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
corr = tips[['total_bill','tip','size']].corr()
corr
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(corr,annot=True,cmap='coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# ## use a example

# %%
import pandas as pd

# %%
df = pd.read_csv('student.csv')
df.head()
# Out:
#   Product_ID        Name     Category    Price  Stock_Quantity    Supplier  \
# 0       P001      Laptop  Electronics  70000.0            50.0  Supplier A
# 1       P002  Smartphone  Electronics  25000.0           100.0  Supplier B
# 2       P003      Tablet  Electronics  18000.0             NaN  Supplier C
# 3       P004     Monitor  Accessories  12000.0            70.0         NaN
# 4       P005    Keyboard  Accessories      NaN           120.0  Supplier D
#
#    prise_missing  New_Price
# 0       70000.00   140000.0
# 1       25000.00    50000.0
# 2       18000.00    36000.0
# 3       12000.00    24000.0
# 4       12718.75        NaN

# %%
df['Price']=df['Price'].fillna(df['Price'].mean())
df
plt.figure(figsize=(19,6))
sns.barplot(x='Category',y='Price',data=df,estimator=sum)
# Out:
# <Axes: xlabel='Category', ylabel='Price'>

# %% [markdown]
# # data set present in seaborn
# ### 📊 Seaborn Built-in Datasets
#
# anscombe – Anscombe’s quartet
#
# attention – Attention experiment data
#
# brain_networks – Brain networks
#
# car_crashes – Car crashes by state
#
# diamonds – Prices of 50,000 diamonds
#
# dots – Dot-estimation task
#
# exercise – Exercise habits of people
#
# flights – Monthly airline passengers
#
# fmri – Brain activity (fmri dataset)
#
# geyser – Old Faithful geyser data
#
# iris – Classic iris flower dataset
#
# mpg – Car fuel economy (miles per gallon)
#
# penguins – Palmer penguins dataset
#
# planets – Exoplanet discovery data
#
# tips – Restaurant tips
#
# titanic – Titanic passengers
#
# dowjones – Dow Jones Index data
#
# healthexp – Health expenditure data
#
# gammas – Gamma radiation data
#
# penguins_size – Penguin body measurements

# %%
df = sns.load_dataset('brain_networks')
