# %% [markdown]
# ## 5 number Summary And Box Plot

# %%
## Minimum,MAximum,Median,Q1,Q3,IQR

# %%
import numpy as np

# %%
lst_marks=[45,32,56,75,89,54,32,89,90,87,67,54,45,98,99,67,74]
minimum,Q1,median,Q3,maximum=np.quantile(lst_marks,[0,0.25,0.50,0.75,1.0])

# %%
minimum,Q1,median,Q3,maximum
# Out:
# (np.float64(32.0),
#  np.float64(54.0),
#  np.float64(67.0),
#  np.float64(89.0),
#  np.float64(99.0))

# %%
IQR=Q3-Q1
print(IQR)
# Out:
# 35.0

# %%
lower_fence=Q1-1.5*(IQR)
higher_fence=Q3+1.5*(IQR)

# %%
lower_fence
# Out:
# np.float64(1.5)

# %%
higher_fence
# Out:
# np.float64(141.5)

# %%
lst_marks=[45,32,56,75,89,54,32,89,90,87,67,54,45,98,99,67,74]

# %%
import seaborn as sns

# %%
sns.boxplot(lst_marks)
# Out:
# <Axes: >

# %%
lst_marks1=[-100,-200,45,32,56,75,89,54,32,89,90,87,67,54,45,98,99,67,74,150,170,180]
minimum,Q1,median,Q3,maximum=np.quantile(lst_marks1,[0,0.25,0.5,0.75,1])
l_f =int( Q1 - 1.5*(Q3-Q1))
h_f = int(Q3 + 1.5*(Q3-Q1))

filtered = [x for x in lst_marks1 if l_f <= x <= h_f]
filtered
# Out:
# [45, 32, 56, 75, 89, 54, 32, 89, 90, 87, 67, 54, 45, 98, 99, 67, 74, 150]

# %%
sns.boxplot(lst_marks)
# Out:
# <Axes: >
