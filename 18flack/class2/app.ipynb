# %%
pip insatll flask
# Out:
# ERROR: unknown command "insatll" - maybe you meant "install"
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install flask
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### import flask

# %%
from flask import Flask

# %% [markdown]
# ### initilize flask

# %%
app = Flask(__name__)

# %% [markdown]
# ### make a home page using @route

# %%
@app.route('/')
def welcame():
    return "welcame to my home sja page"

# %% [markdown]
# ### entry point

# %%
if __name__ == "__main__":
    app.run(debug=True)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: on
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
#  * Restarting with stat
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/Users/apple/AI_ML/venv/lib/python3.12/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/Users/apple/AI_ML/venv/lib/python3.12/site-packages/traitlets/config/application.py", line 1074, in launch_instance
#     app.initialize(argv)
#   File "/Users/apple/AI_ML/venv/lib/python3.12/site-packages/traitlets/config/application.py", line 118, in inner
#     return method(app, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...
