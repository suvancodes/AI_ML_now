# %% [markdown]
# ### Creating a Linked List

# %%
class node:
    def __init__(self, data):
        self.data = data
        self.next = None
        
class LL:
    def __init__(self):
        self.head = None
    
    def add(self, data):
        newnode = node(data)
        if self.head == None:
            self.head = newnode
            return
        
        temp = self.head
        while temp.next != None:
            temp = temp.next
        
        temp.next = newnode

    def add_array(self, arr):
        for data in arr:
            self.add(data)
        
    def add_head(self, data):
        newnode = node(data)
        newnode.next = self.head
        self.head = newnode
        
    def add_idx(self, data, i):
        newnode = node(data)
        temp = self.head
        k = 1
        
        if i == 1:
            newnode.next = self.head
            self.head = newnode
            return
        
        while k != i - 1:
            temp = temp.next
            k += 1
            
        newnode.next = temp.next
        temp.next = newnode
    
    def delete(self, data):
        if self.head is None:
            return
        
        if self.head.data == data:
            self.head = self.head.next
            return
        
        temp = self.head
        
        while temp.next is not None:
            if temp.next.data == data:
                temp.next = temp.next.next
                return
            
            temp = temp.next
    
    def delete_head(self):
        if self.head == None:
            print('Empty Linked List')
            return
        
        temp = self.head
        self.head = temp.next
        temp.next = None
    
    def display(self):
        temp = self.head
        
        while temp:
            print(temp.data, end='->')
            temp = temp.next
        
        print("none")


ll = LL()

arr = [10, 20, 30, 40, 50]

ll.add_array(arr)

ll.display()
# Out:
# 10->20->30->40->50->none

# %% [markdown]
# ---
#
# ## 22. Intersection of Two Linked Lists
#
# Find the node where two linked lists intersect.
#
# Example:
#
# ```text
# A: 4 → 1
#           ↘
#             8 → 4 → 5
#           ↗
# B: 5 → 6 → 1
# ```
#
# **Input**
#
# ```text
# listA = [4, 1, 8, 4, 5]
# listB = [5, 6, 1, 8, 4, 5]
# intersection = 8
# ```
#
# **Output**
#
# ```text
# 8
# ```
#
# **Complexity target**
#
# * Time: `O(n + m)`
# * Space: `O(1)`
#
# 🔥 Classic placement problem.
#
# ---
#
# # 🔴 LEVEL 3 — Medium / Important Interview Problems
#
# ## 23. Add Two Numbers
#
# Each linked list represents a number in **reverse order**.
#
# **Input**
#
# ```text
# l1 = [2, 4, 3]
# l2 = [5, 6, 4]
# ```
#
# Meaning:
#
# ```text
# 342 + 465 = 807
# ```
#
# **Output**
#
# ```text
# [7, 0, 8]
# ```
#
# **Complexity**
#
# * Time: `O(max(n,m))`
# * Space: `O(max(n,m))` for output
#
# ---
#
# ## 24. Reverse Linked List in Groups of K
#
# Reverse nodes in groups of `k`.
#
# **Input**
#
# ```text
# head = [1, 2, 3, 4, 5, 6, 7, 8]
# k = 3
# ```
#
# **Output**
#
# ```text
# [3, 2, 1, 6, 5, 4, 7, 8]
# ```
#
# The remaining group smaller than `k` stays unchanged.
#
# **Complexity**
#
# * Time: `O(n)`
# * Space: `O(1)` iterative target
#
# 🔥 **Very important placement problem.**
#
# ---
#
# ## 25. Rotate Linked List Right by K
#
# Rotate the list to the right by `k` positions.
#
# **Input**
#
# ```text
# head = [1, 2, 3, 4, 5]
# k = 2
# ```
#
# **Output**
#
# ```text
# [4, 5, 1, 2, 3]
# ```
#
# **Complexity**
#
# * Time: `O(n)`
# * Space: `O(1)`
#
# 💡 Don't repeatedly rotate one position. That's unnecessarily `O(nk)`.
#
# ---
#
# ## 26. Sort a Linked List
#
# Sort the linked list in ascending order.
#
# **Input**
#
# ```text
# head = [4, 2, 1, 3]
# ```
#
# **Output**
#
# ```text
# [1, 2, 3, 4]
# ```
#
# **Target complexity**
#
# * Time: `O(n log n)`
# * Space: `O(log n)` recursion stack
#
# 💡 Pattern: **Merge Sort**
#
# This is important because linked lists are particularly well-suited for merge sort.
#
# ---
#
# ## 27. Delete a Node Given Only That Node
#
# You are given a node that needs to be deleted, but **you don't have access to the head**.
#
# The node is guaranteed not to be the last node.
#
# **Input**
#
# ```text
# head = [4, 5, 1, 9]
# node = 5
# ```
#
# **Output**
#
# ```text
# [4, 1, 9]
# ```
#
# **Complexity**
#
# * Time: `O(1)`
# * Space: `O(1)`
#
# 🔥 Classic interview trick.
#
# ---
#
# ## 28. Partition List Around X
#
# Rearrange the list so that:
#
# ```text
# nodes < x
# ```
#
# come before:
#
# ```text
# nodes >= x
# ```
#
# Preserve the original relative order within each group.
#
# **Input**
#
# ```text
# head = [1, 4, 3, 2, 5, 2]
# x = 3
# ```
#
# **Output**
#
# ```text
# [1, 2, 2, 4, 3, 5]
# ```
#
# **Complexity**
#
# * Time: `O(n)`
# * Space: `O(1)`
#
# 💡 Pattern: **two linked-list chains**
#
# ---
#
# ## 29. Reorder Linked List
#
# Rearrange:
#
# ```text
# L0 → L1 → L2 → ... → Ln
# ```
#
# into:
#
# ```text
# L0 → Ln → L1 → Ln-1 → L2 → Ln-2 → ...
# ```
#
# **Input**
#
# ```text
# head = [1, 2, 3, 4, 5]
# ```
#
# **Output**
#
# ```text
# [1, 5, 2, 4, 3]
# ```
#
# For:
#
# ```text
# [1, 2, 3, 4]
# ```
#
# Output:
#
# ```text
# [1, 4, 2, 3]
# ```
#
# **Complexity**
#
# * Time: `O(n)`
# * Space: `O(1)`
#
# 🔥 This combines **three major patterns**:
#
# ```text
# Find middle
#      ↓
# Reverse second half
#      ↓
# Merge alternately
# ```
#
# ---
#
# ## 30. Clone a Linked List with Random Pointer
#
# Each node contains:
#
# ```text
# next
# random
# ```
#
# `random` can point to any node or `NULL`.
#
# **Input**
#
# ```text
# Nodes:  [7, 13, 11, 10, 1]
#
# random:
# 7  → NULL
# 13 → 7
# 11 → 1
# 10 → 11
# 1  → 7
# ```
#
# **Output**
#
# A **deep copy** with exactly the same `next` and `random` relationships.
#
# Conceptually:
#
# ```text
# Original: 7 → 13 → 11 → 10 → 1
#             ↘    ↘    ↘
#              ... random pointers ...
#
# Clone:    7' → 13' → 11' → 10' → 1'
# ```
#
# The cloned nodes must be **different objects** from the original nodes.
#
# **Target complexity**
#
# * Time: `O(n)`
# * Space: `O(1)` auxiliary
#
# 💡 There is also a simpler solution using a hash map with `O(n)` extra space. **Know both.**
#
# ---
#
# # 🧠 Your 30-Question Coverage
#
# | Concept                | Questions      |
# | ---------------------- | -------------- |
# | Traversal              | 1–3            |
# | Length                 | 2              |
# | Insertion              | 4–6            |
# | Deletion               | 7–9            |
# | Searching              | 3              |
# | Counting               | 10             |
# | Slow/Fast pointers     | 11, 15, 18, 19 |
# | Two-pointer gap        | 12             |
# | Reversal               | 13, 14, 24     |
# | Palindrome             | 15             |
# | Duplicates             | 16, 17         |
# | Cycle detection        | 18             |
# | Cycle start            | 19             |
# | Cycle removal          | 20             |
# | Merge                  | 21, 29         |
# | Intersection           | 22             |
# | Carry handling         | 23             |
# | K-group manipulation   | 24             |
# | Rotation               | 25             |
# | Merge sort             | 26             |
# | Constant-time deletion | 27             |
# | Partitioning           | 28             |
# | Reordering             | 29             |
# | Random pointers        | 30             |
#
# ### 🎯 The patterns you should be able to recognize after these 30
#
# ```text
# Traversal
#    ↓
# Pointer manipulation
#    ↓
# Slow/Fast pointers
#    ↓
# Two-pointer gap
#    ↓
# In-place reversal
#    ↓
# Cycle detection
#    ↓
# Merge
#    ↓
# Divide & conquer
#    ↓
# Complex pointer rearrangement
# ```
#
# **One important rule:** don't look at the pattern column while solving. First read only the problem. Try to identify the approach yourself. If you immediately know "this is slow-fast pointer," you're practicing recognition rather than problem solving.
#
# For placement preparation, I'd solve them in **this exact order**, and for every problem write down:
#
# ```text
# 1. Approach
# 2. Why it works
# 3. Code
# 4. Time complexity
# 5. Space complexity
# 6. Edge cases
# ```
#
# That will give you much better placement preparation than simply grinding 100 linked-list questions.

# %% [markdown]
# ## 11. Find the Middle of Linked List
#
# If there are two middle nodes, return the **second middle**.
#
# **Input**
#
# ```text
# head = [10, 20, 30, 40, 50]
# ```
#
# **Output**
#
# ```text
# 30
# ```
#
# **Complexity**
#
# * Time: `O(n)`
# * Space: `O(1)`
#
# 💡 Pattern: **slow + fast pointer**
#
# ### Ans -> https://leetcode.com/problems/middle-of-the-linked-list/submissions/2131242257/

# %% [markdown]
# ## 12. Find the Nth Node from the End
#
# Return the `n`th node from the end.
#
# **Input**
#
# ```text
# head = [10, 20, 30, 40, 50]
# n = 2
# ```
#
# **Output**
#
# ```text
# 40
# ```
# ### ans -> https://leetcode.com/problems/remove-nth-node-from-end-of-list/submissions/2131242257/

# %% [markdown]
# ## 13. Reverse a Linked List — Iterative
#
# Reverse the linked list.
#
# **Input**
#
# ```text
# head = [10, 20, 30, 40, 50]
# ```
#
# **Output**
#
# ```text
#
# [50, 40, 30, 20, 10]
# ```
#
# **Complexity**
#
# * Time: `O(n)`
# * Space: `O(1)`
#
# 🔥 This is a **must-know placement problem**.
# ### ans -> https://leetcode.com/problems/reverse-linked-list/submissions/2131242257/

# %% [markdown]
# ## 15. Check if Linked List is Palindrome
#
# Determine whether the list reads the same forward and backward.
#
# **Input**
#
# ```text
# head = [1, 2, 3, 2, 1]
# ```
#
# **Output**
#
# ```text
# true
# ```
#
# **Complexity target**
#
# * Time: `O(n)`
# * Space: `O(1)`
#
# 💡 Pattern:
# `middle → reverse second half → compare`
#
# ### ans -> https://leetcode.com/problems/palindrome-linked-list/submissions/2131242257/

# %% [markdown]
# ## 16. Remove Duplicates from Sorted Linked List
#
# Remove duplicate values from a **sorted** list.
#
# **Input**
#
# ```text
# head = [1, 1, 2, 3, 3, 3, 4]
# ```
#
# **Output**
#
# ```text
# [1, 2, 3, 4]
# ```
#
# **Complexity**
#
# * Time: `O(n)`
# * Space: `O(1)`
# ### ans -> https://leetcode.com/problems/remove-duplicates-from-sorted-list/submissions/2131242257/

# %% [markdown]
# ## 18. Detect Cycle in Linked List
#
# Determine whether the linked list contains a cycle.
#
# Represent the cycle using `pos`, where the tail connects to index `pos`. `pos = -1` means no cycle.
#
# **Input**
#
# ```text
# head = [3, 2, 0, -4]
# pos = 1
# ```
#
# **Output**
#
# ```text
# true
# ```
#
# **Complexity**
#
# * Time: `O(n)`
# * Space: `O(1)`
#
# 💡 Pattern: **Floyd's Cycle Detection**
# ### ans -> https://leetcode.com/problems/linked-list-cycle/submissions/2131242257/

# %% [markdown]
# ## 19. Find Starting Node of Cycle
#
# Return the node where the cycle begins.
#
# **Input**
#
# ```text
# head = [3, 2, 0, -4]
# pos = 1
# ```
#
# **Output**
#
# ```text
# 2
# ```
#
# **Complexity**
#
# * Time: `O(n)`
# * Space: `O(1)`
#
# 🔥 Very important follow-up to Q18.
# ### ans -> https://leetcode.com/problems/linked-list-cycle-ii/submissions/2131242257/

# %% [markdown]
# ## 20. Remove Cycle
#
# Given a linked list containing a cycle, remove the cycle while keeping all nodes.
#
# **Input**
#
# ```text
# head = [1, 2, 3, 4, 5]
# pos = 2
# ```
#
# Cycle:
#
# ```text
# 5 → 3
# ```
#
# **Output**
#
# ```text
# [1, 2, 3, 4, 5]
# ```
#
# The resulting list must be:
#
# ```text
# 1 → 2 → 3 → 4 → 5 → NULL
# ```
#
# **Complexity**
#
# * Time: `O(n)`
# * Space: `O(1)`
# ### ans ->https://www.geeksforgeeks.org/problems/remove-loop-in-linked-list/1

# %% [markdown]
# ## 21. Merge Two Sorted Linked Lists
#
# Merge two sorted lists into one sorted list.
#
# **Input**
#
# ```text
# list1 = [1, 3, 5]
# list2 = [2, 4, 6]
# ```
#
# **Output**
#
# ```text
# [1, 2, 3, 4, 5, 6]
# ```
#
# **Complexity**
#
# * Time: `O(n + m)`
# * Space: `O(1)` auxiliary
