# %% [markdown]
# ## FOUNDATION
# Arrays → Strings → Sorting → Searching → Hashing
#                     ↓
# ## PATTERNS
# Two Pointers → Sliding Window → Prefix Sum → Binary Search
#                     ↓
# ## DATA STRUCTURES
# Linked List → Stack → Queue → Heap
#                     ↓
# ## NON-LINEAR
# Trees → BST → Graphs
#                     ↓
# ## ADVANCED
# Recursion → Backtracking → DP
#                     ↓
# ## PLACEMENT MODE
# Mixed Problems → Company Questions → Timed Tests → Mock Interviews
