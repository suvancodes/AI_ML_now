# %% [markdown]
# ## Diabetes Predictions

# %%
from sklearn.datasets import load_diabetes

# %%
dataset=load_diabetes()

# %%
dataset
# Out:
# {'data': array([[ 0.03807591,  0.05068012,  0.06169621, ..., -0.00259226,
#           0.01990749, -0.01764613],
#         [-0.00188202, -0.04464164, -0.05147406, ..., -0.03949338,
#          -0.06833155, -0.09220405],
#         [ 0.08529891,  0.05068012,  0.04445121, ..., -0.00259226,
#           0.00286131, -0.02593034],
#         ...,
#         [ 0.04170844,  0.05068012, -0.01590626, ..., -0.01107952,
#          -0.04688253,  0.01549073],
#         [-0.04547248, -0.04464164,  0.03906215, ...,  0.02655962,
#           0.04452873, -0.02593034],
#         [-0.04547248, -0.04464164, -0.0730303 , ..., -0.03949338,
#          -0.00422151,  0.00306441]], shape=(442, 10)),
#  'target': array([151.,  75., 141., 206., 135.,  97., 138.,  63., 110., 310., 101.,
#          69., 179., 185., 118., 171., 166., 144.,  97., 168.,  68.,  49.,
#          68., 245., 184., 202., 137.,  85., 131., 283., 129.,  59., 341.,
#          87.,  65., 102., 265., 276., 252.,  90., 100.,  55.,  61.,  92.,
#         259.,  53., 190., 142.,  75., 142., 155., 225.,  59., 104., 182.,
#         128.,  52.,  37., 170., 170.,  61., 144.,  52., 128.,  71., 163.,
#         150.,  97., 160., 178.,  48., 270., 202., 111.,  85.,  42., 170.,
#         200., 252., 113., 143.,  51.,  52., 210.,  65., 141.,  55., 134.,
#          42., 111.,  98., 164.,  48.,  96.,  90., 162., 150., 279.,  92.,
#          83., 128., 102., 302., 198.,  95.,  53., 134., 144., 232.,  81.,
#         104.,  59., 246., 297., 258., 229., 275., 281., 179., 200., 200.,
#         173., 180.,  84., 121., 161.,  99., 109., 115., 268., 274., 158.,
#         107.,  83., 103., 272.,  85., 280., 336., 281., 118., 317., 235.,
#          60., 174., 259., 178., 128.,  96., 126., 288.,  88., 292.,  71.,
#         197., 186.,  25.,  84.,  96., 195.,  53., 217., 172., 131., 214.,
#          59.,  70., 220., 268., 152.,  47.,  74., 295., 101., 151., 127.,
#         237., 225.,  81., 151., 107.,  64., 138., 185., 265., 101., 137.,
#         143., 141.,  79., 292., 178.,  91., 116.,  86., 122.,  72., 129.,
#         142.,  90., 158.,  39., 196., 222., 277.,  99., 196., 202., 155.,
#          77., 191.,  70.,  73.,  49.,  65., 263., 248., 296., 214., 185.,
#          78.,  93., 252., 150.,  77., 208.,  77., 108., 160.,  53., 220.,
#         154., 259.,  90., 246., 124.,  67.,  72., 257., 262., 275., 177.,
#          71.,  47., 187., 125.,  78.,  51., 258., 215., 303., 243.,  91.,
#         150., 310., 153., 346.,  63.,  89.,  50.,  39., 103., 308., 116.,
#         145.,  74.,  45., 115., 264.,  87., 202., 127., 182., 241.,  66.,
#          94., 283.,  64., 102., 200., 265.,  94., 230., 181., 156., 233.,
#          60., 219.,  80.,  68., 332., 248.,  84., 200.,  55.,  85.,  89.,
#          31., 129.,  83., 275.,  65., 198., 236., 253., 124.,  44., 172.,
#         114., 142., 109., 180., 144., 163., 147.,  97., 220., 190., 109.,
#         191., 122., 230., 242., 248., 249., 192., 131., 237.,  78., 135.,
#         244., 199., 270., 164.,  72.,  96., 306.,  91., 214.,  95., 216.,
#         263., 178., 113., 200., 139., 139.,  88., 148.,  88., 243.,  71.,
#          77., 109., 272.,  60.,  54., 221.,  90., 311., 281., 182., 321.,
#          58., 262., 206., 233., 242., 123., 167.,  63., 197.,  71., 168.,
#         140., 217., 121., 235., 245.,  40.,  52., 104., 132.,  88.,  69.,
#         219.,  72., 201., 110.,  51., 277.,  63., 118.,  69., 273., 258.,
#          43., 198., 242., 232., 175.,  93., 168., 275., 293., 281.,  72.,
#         140., 189., 181., 209., 136., 261., 113., 131., 174., 257.,  55.,
#          84.,  42., 146., 212., 233.,  91., 111., 152., 120.,  67., 310.,
#          94., 183.,  66., 173.,  72.,  49.,  64.,  48., 178., 104., 132.,
#         220.,  57.]),
#  'frame': None,
#  'DESCR': '.. _diabetes_dataset:\n\nDiabetes dataset\n----------------\n\nTen baseline variables, age, sex, body mass index, average blood\npressure, and six blood serum measurements were obtained for each of n =\n442 diabetes patients, as well as the response of interest, a\nquantitative measure of disease progression one year after baseline.\n\n**Data Set Characteristics:**\n\n:Number of Instances: 442\n\n:Number of Attributes: First 10 columns are numeric predictive values\n\n:Target: Column 11 is a quantitative measure of disease progression one year after baseline\n\n:Attribute Information:\n    - age     age in years\n    - sex\n    - bmi     body mass index\n    - bp      average blood pressure\n    - s1      tc, total serum cholesterol\n    - s2      ldl, low-density lipoproteins\n    - s3      hdl, high-density lipoproteins\n    - s4      tch, total cholesterol / HDL\n    - s5      ltg, possibly log of serum triglycerides level\n    - s6      glu, blood sugar level\n\nNote: Each of these 10 feature variables have been mean centered and scaled by the standard deviation times the square root of `n_samples` (i.e. the sum of squares of each column totals 1).\n\nSource URL:\nhttps://www4.stat.ncsu.edu/~boos/var.select/diabetes.html\n\nFor more information see:\nBradley Efron, Trevor Hastie, Iain Johnstone and Robert Tibshirani (2004) "Least Angle Regression," Annals of Statistics (with discussion), 407-499.\n(https://web.stanford.edu/~hastie/Papers/LARS/LeastAngle_2002.pdf)\n',
#  'feature_names': ['age',
#   'sex',
#   'bmi',
#   'bp',
#   's1',
#   's2',
#   's3',
#   's4',
#   's5',
#   's6'],
#  'data_filename': 'diabetes_data_raw.csv.gz',
#  'target_filename': 'diabetes_target.csv.gz',
#  'data_module': 'sklearn.datasets.data'}

# %%
print(dataset['DESCR'])
# Out:
# .. _diabetes_dataset:
#
# Diabetes dataset
# ----------------
#
# Ten baseline variables, age, sex, body mass index, average blood
# pressure, and six blood serum measurements were obtained for each of n =
# 442 diabetes patients, as well as the response of interest, a
# quantitative measure of disease progression one year after baseline.
#
# **Data Set Characteristics:**
#
# :Number of Instances: 442
#
# :Number of Attributes: First 10 columns are numeric predictive values
#
# :Target: Column 11 is a quantitative measure of disease progression one year after baseline
#
# :Attribute Information:
#     - age     age in years
#     - sex
#     - bmi     body mass index
#     - bp      average blood pressure
#     - s1      tc, total serum cholesterol
#     - s2      ldl, low-density lipoproteins
#     - s3      hdl, high-density lipoproteins
#     - s4      tch, total cholesterol / HDL
#     - s5      ltg, possibly log of serum triglycerides level
#     - s6      glu, blood sugar level
#
# Note: Each of these 10 feature variables have been mean centered and scaled by the standard deviation times the square root of `n_samples` (i.e. the sum of squares of each column totals 1).
#
# Source URL:
# https://www4.stat.ncsu.edu/~boos/var.select/diabetes.html
#
# For more information see:
# Bradley Efron, Trevor Hastie, Iain Johnstone and Robert Tibshirani (2004) "Least Angle Regression," Annals of Statistics (with discussion), 407-499.
# (https://web.stanford.edu/~hastie/Papers/LARS/LeastAngle_2002.pdf)

# %%
dataset
# Out:
# {'data': array([[ 0.03807591,  0.05068012,  0.06169621, ..., -0.00259226,
#           0.01990749, -0.01764613],
#         [-0.00188202, -0.04464164, -0.05147406, ..., -0.03949338,
#          -0.06833155, -0.09220405],
#         [ 0.08529891,  0.05068012,  0.04445121, ..., -0.00259226,
#           0.00286131, -0.02593034],
#         ...,
#         [ 0.04170844,  0.05068012, -0.01590626, ..., -0.01107952,
#          -0.04688253,  0.01549073],
#         [-0.04547248, -0.04464164,  0.03906215, ...,  0.02655962,
#           0.04452873, -0.02593034],
#         [-0.04547248, -0.04464164, -0.0730303 , ..., -0.03949338,
#          -0.00422151,  0.00306441]], shape=(442, 10)),
#  'target': array([151.,  75., 141., 206., 135.,  97., 138.,  63., 110., 310., 101.,
#          69., 179., 185., 118., 171., 166., 144.,  97., 168.,  68.,  49.,
#          68., 245., 184., 202., 137.,  85., 131., 283., 129.,  59., 341.,
#          87.,  65., 102., 265., 276., 252.,  90., 100.,  55.,  61.,  92.,
#         259.,  53., 190., 142.,  75., 142., 155., 225.,  59., 104., 182.,
#         128.,  52.,  37., 170., 170.,  61., 144.,  52., 128.,  71., 163.,
#         150.,  97., 160., 178.,  48., 270., 202., 111.,  85.,  42., 170.,
#         200., 252., 113., 143.,  51.,  52., 210.,  65., 141.,  55., 134.,
#          42., 111.,  98., 164.,  48.,  96.,  90., 162., 150., 279.,  92.,
#          83., 128., 102., 302., 198.,  95.,  53., 134., 144., 232.,  81.,
#         104.,  59., 246., 297., 258., 229., 275., 281., 179., 200., 200.,
#         173., 180.,  84., 121., 161.,  99., 109., 115., 268., 274., 158.,
#         107.,  83., 103., 272.,  85., 280., 336., 281., 118., 317., 235.,
#          60., 174., 259., 178., 128.,  96., 126., 288.,  88., 292.,  71.,
#         197., 186.,  25.,  84.,  96., 195.,  53., 217., 172., 131., 214.,
#          59.,  70., 220., 268., 152.,  47.,  74., 295., 101., 151., 127.,
#         237., 225.,  81., 151., 107.,  64., 138., 185., 265., 101., 137.,
#         143., 141.,  79., 292., 178.,  91., 116.,  86., 122.,  72., 129.,
#         142.,  90., 158.,  39., 196., 222., 277.,  99., 196., 202., 155.,
#          77., 191.,  70.,  73.,  49.,  65., 263., 248., 296., 214., 185.,
#          78.,  93., 252., 150.,  77., 208.,  77., 108., 160.,  53., 220.,
#         154., 259.,  90., 246., 124.,  67.,  72., 257., 262., 275., 177.,
#          71.,  47., 187., 125.,  78.,  51., 258., 215., 303., 243.,  91.,
#         150., 310., 153., 346.,  63.,  89.,  50.,  39., 103., 308., 116.,
#         145.,  74.,  45., 115., 264.,  87., 202., 127., 182., 241.,  66.,
#          94., 283.,  64., 102., 200., 265.,  94., 230., 181., 156., 233.,
#          60., 219.,  80.,  68., 332., 248.,  84., 200.,  55.,  85.,  89.,
#          31., 129.,  83., 275.,  65., 198., 236., 253., 124.,  44., 172.,
#         114., 142., 109., 180., 144., 163., 147.,  97., 220., 190., 109.,
#         191., 122., 230., 242., 248., 249., 192., 131., 237.,  78., 135.,
#         244., 199., 270., 164.,  72.,  96., 306.,  91., 214.,  95., 216.,
#         263., 178., 113., 200., 139., 139.,  88., 148.,  88., 243.,  71.,
#          77., 109., 272.,  60.,  54., 221.,  90., 311., 281., 182., 321.,
#          58., 262., 206., 233., 242., 123., 167.,  63., 197.,  71., 168.,
#         140., 217., 121., 235., 245.,  40.,  52., 104., 132.,  88.,  69.,
#         219.,  72., 201., 110.,  51., 277.,  63., 118.,  69., 273., 258.,
#          43., 198., 242., 232., 175.,  93., 168., 275., 293., 281.,  72.,
#         140., 189., 181., 209., 136., 261., 113., 131., 174., 257.,  55.,
#          84.,  42., 146., 212., 233.,  91., 111., 152., 120.,  67., 310.,
#          94., 183.,  66., 173.,  72.,  49.,  64.,  48., 178., 104., 132.,
#         220.,  57.]),
#  'frame': None,
#  'DESCR': '.. _diabetes_dataset:\n\nDiabetes dataset\n----------------\n\nTen baseline variables, age, sex, body mass index, average blood\npressure, and six blood serum measurements were obtained for each of n =\n442 diabetes patients, as well as the response of interest, a\nquantitative measure of disease progression one year after baseline.\n\n**Data Set Characteristics:**\n\n:Number of Instances: 442\n\n:Number of Attributes: First 10 columns are numeric predictive values\n\n:Target: Column 11 is a quantitative measure of disease progression one year after baseline\n\n:Attribute Information:\n    - age     age in years\n    - sex\n    - bmi     body mass index\n    - bp      average blood pressure\n    - s1      tc, total serum cholesterol\n    - s2      ldl, low-density lipoproteins\n    - s3      hdl, high-density lipoproteins\n    - s4      tch, total cholesterol / HDL\n    - s5      ltg, possibly log of serum triglycerides level\n    - s6      glu, blood sugar level\n\nNote: Each of these 10 feature variables have been mean centered and scaled by the standard deviation times the square root of `n_samples` (i.e. the sum of squares of each column totals 1).\n\nSource URL:\nhttps://www4.stat.ncsu.edu/~boos/var.select/diabetes.html\n\nFor more information see:\nBradley Efron, Trevor Hastie, Iain Johnstone and Robert Tibshirani (2004) "Least Angle Regression," Annals of Statistics (with discussion), 407-499.\n(https://web.stanford.edu/~hastie/Papers/LARS/LeastAngle_2002.pdf)\n',
#  'feature_names': ['age',
#   'sex',
#   'bmi',
#   'bp',
#   's1',
#   's2',
#   's3',
#   's4',
#   's5',
#   's6'],
#  'data_filename': 'diabetes_data_raw.csv.gz',
#  'target_filename': 'diabetes_target.csv.gz',
#  'data_module': 'sklearn.datasets.data'}

# %%
import pandas as pd
df_diabetes=pd.DataFrame(dataset.data,columns=['age',
  'sex',
  'bmi',
  'bp',
  's1',
  's2',
  's3',
  's4',
  's5',
  's6'])
df_diabetes.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6
# 0 -0.002592  0.019907 -0.017646
# 1 -0.039493 -0.068332 -0.092204
# 2 -0.002592  0.002861 -0.025930
# 3  0.034309  0.022688 -0.009362
# 4 -0.002592 -0.031988 -0.046641

# %%
## Independent and dependent features
X=df_diabetes
y=dataset['target']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=10)

# %%
X_train.head()
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 249 -0.012780 -0.044642  0.060618  0.052858  0.047965  0.029375 -0.017629
# 389 -0.005515  0.050680  0.001339 -0.084856 -0.011201 -0.016658  0.048640
# 121  0.063504 -0.044642  0.017506  0.021872  0.008063  0.021546 -0.036038
# 195  0.027178  0.050680  0.025051  0.014987  0.025950  0.048477 -0.039719
# 69   0.016281 -0.044642 -0.046085 -0.005670 -0.075870 -0.061438 -0.013948
#
#            s4        s5        s6
# 249  0.034309  0.070207  0.007207
# 389 -0.039493 -0.041176 -0.088062
# 121  0.034309  0.019907  0.011349
# 195  0.034309  0.007838  0.023775
# 69  -0.039493 -0.051404  0.019633

# %%
## correlation
X_train.corr()
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# age  1.000000  0.197408  0.198359  0.394903  0.238375  0.192920 -0.128403
# sex  0.197408  1.000000  0.108261  0.221914  0.057674  0.180315 -0.379464
# bmi  0.198359  0.108261  1.000000  0.356324  0.226047  0.248146 -0.395021
# bp   0.394903  0.221914  0.356324  1.000000  0.238295  0.165632 -0.192505
# s1   0.238375  0.057674  0.226047  0.238295  1.000000  0.872781  0.006313
# s2   0.192920  0.180315  0.248146  0.165632  0.872781  1.000000 -0.265114
# s3  -0.128403 -0.379464 -0.395021 -0.192505  0.006313 -0.265114  1.000000
# s4   0.227110  0.324882  0.412826  0.249141  0.559626  0.684840 -0.754616
# s5   0.314151  0.150956  0.435505  0.420236  0.566312  0.325759 -0.370523
# s6   0.351570  0.193322  0.358273  0.368882  0.356280  0.315890 -0.297055
#
#            s4        s5        s6
# age  0.227110  0.314151  0.351570
# sex  0.324882  0.150956  0.193322
# bmi  0.412826  0.435505  0.358273
# bp   0.249141  0.420236  0.368882
# s1   0.559626  0.566312  0.356280
# s2   0.684840  0.325759  0.315890
# s3  -0.754616 -0.370523 -0.297055
# s4   1.000000  0.609983  0.436311
# s5   0.609983  1.000000  0.490970
# s6   0.436311  0.490970  1.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(15,10))
sns.heatmap(X_train.corr(),annot=True)
# Out:
# <Axes: >

# %%
from sklearn.tree import DecisionTreeRegressor
regressor=DecisionTreeRegressor()
regressor.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
##Visualize the Decision Tree
import matplotlib.pyplot as plt
from sklearn import tree
plt.figure(figsize=(15,10))
tree.plot_tree(regressor,filled=True)
# Out:
# [Text(0.6730054358424337, 0.975, 'x[8] <= 0.022\nsquared_error = 5757.456\nsamples = 309\nvalue = 152.738'),
#  Text(0.4704502242589704, 0.925, 'x[2] <= 0.005\nsquared_error = 4016.257\nsamples = 205\nvalue = 123.444'),
#  Text(0.571727830050702, 0.95, 'True  '),
#  Text(0.3717214313572543, 0.875, 'x[7] <= 0.031\nsquared_error = 2592.764\nsamples = 148\nvalue = 107.615'),
#  Text(0.3007751560062403, 0.825, 'x[0] <= 0.022\nsquared_error = 2220.402\nsamples = 127\nvalue = 101.008'),
#  Text(0.2374707488299532, 0.775, 'x[3] <= 0.115\nsquared_error = 2062.541\nsamples = 98\nvalue = 93.898'),
#  Text(0.23435062402496099, 0.725, 'x[8] <= -0.009\nsquared_error = 1928.519\nsamples = 97\nvalue = 92.639'),
#  Text(0.19608034321372855, 0.675, 'x[2] <= 0.003\nsquared_error = 1459.603\nsamples = 78\nvalue = 87.577'),
#  Text(0.19296021840873634, 0.625, 'x[3] <= -0.001\nsquared_error = 1312.285\nsamples = 77\nvalue = 86.117'),
#  Text(0.15815132605304213, 0.575, 'x[3] <= -0.007\nsquared_error = 1289.903\nsamples = 66\nvalue = 89.773'),
#  Text(0.12129485179407176, 0.525, 'x[1] <= 0.003\nsquared_error = 1088.055\nsamples = 62\nvalue = 85.903'),
#  Text(0.07332293291731669, 0.475, 'x[5] <= -0.037\nsquared_error = 1247.692\nsamples = 44\nvalue = 91.614'),
#  Text(0.0514820592823713, 0.425, 'x[3] <= -0.031\nsquared_error = 699.601\nsamples = 19\nvalue = 75.632'),
#  Text(0.0374414976599064, 0.375, 'x[0] <= -0.006\nsquared_error = 291.75\nsamples = 16\nvalue = 67.0'),
#  Text(0.0249609984399376, 0.325, 'x[3] <= -0.056\nsquared_error = 178.521\nsamples = 13\nvalue = 61.308'),
#  Text(0.0124804992199688, 0.275, 'x[5] <= -0.07\nsquared_error = 104.408\nsamples = 7\nvalue = 68.857'),
#  Text(0.0062402496099844, 0.225, 'x[5] <= -0.08\nsquared_error = 6.25\nsamples = 2\nvalue = 57.5'),
#  Text(0.0031201248049922, 0.175, 'squared_error = 0.0\nsamples = 1\nvalue = 60.0'),
#  Text(0.0093603744149766, 0.175, 'squared_error = 0.0\nsamples = 1\nvalue = 55.0'),
#  Text(0.0187207488299532, 0.225, 'x[6] <= 0.054\nsquared_error = 71.44\nsamples = 5\nvalue = 73.4'),
#  Text(0.015600624024960999, 0.175, 'x[3] <= -0.071\nsquared_error = 24.5\nsamples = 4\nvalue = 77.0'),
#  Text(0.0124804992199688, 0.125, 'x[3] <= -0.106\nsquared_error = 4.222\nsamples = 3\nvalue = 74.333'),
#  Text(0.0093603744149766, 0.075, 'squared_error = 0.0\nsamples = 1\nvalue = 77.0'),
#  Text(0.015600624024960999, 0.075, 'x[8] <= -0.054\nsquared_error = 1.0\nsamples = 2\nvalue = 73.0'),
#  Text(0.0124804992199688, 0.025, 'squared_error = 0.0\nsamples = 1\nvalue = 72.0'),
#  Text(0.0187207488299532, 0.025, 'squared_error = 0.0\nsamples = 1\nvalue = 74.0'),
#  Text(0.0187207488299532, 0.125, 'squared_error = 0.0\nsamples = 1\nvalue = 85.0'),
#  Text(0.0218408736349454, 0.175, 'squared_error = 0.0\nsamples = 1\nvalue = 59.0'),
#  Text(0.0374414976599064, 0.275, 'x[3] <= -0.049\nsquared_error = 120.917\nsamples = 6\nvalue = 52.5'),
#  Text(0.031201248049921998, 0.225, 'x[5] <= -0.052\nsquared_error = 20.222\nsamples = 3\nvalue = 42.333'),
#  Text(0.028081123244929798, 0.175, 'x[5] <= -0.081\nsquared_error = 6.25\nsamples = 2\nvalue = 39.5'),
#  Text(0.0249609984399376, 0.125, 'squared_error = 0.0\nsamples = 1\nvalue = 37.0'),
#  Text(0.031201248049921998, 0.125, 'squared_error = 0.0\nsamples = 1\nvalue = 42.0'),
#  Text(0.0343213728549142, 0.175, 'squared_error = 0.0\nsamples = 1\nvalue = 48.0'),
#  Text(0.0436817472698908, 0.225, 'x[8] <= -0.032\nsquared_error = 14.889\nsamples = 3\nvalue = 62.667'),
#  Text(0.0405616224648986, 0.175, 'x[5] <= -0.061\nsquared_error = 1.0\nsamples = 2\nvalue = 60.0'),
#  Text(0.0374414976599064, 0.125, 'squared_error = 0.0\nsamples = 1\nvalue = 61.0'),
#  Text(0.0436817472698908, 0.125, 'squared_error = 0.0\nsamples = 1\nvalue = 59.0'),
#  Text(0.046801872074883, 0.175, 'squared_error = 0.0\nsamples = 1\nvalue = 68.0'),
#  Text(0.0499219968798752, 0.325, 'x[9] <= -0.014\nsquared_error = 33.556\nsamples = 3\nvalue = 91.667'),
#  Text(0.046801872074883, 0.275, 'squared_error = 0.0\nsamples = 1\nvalue = 84.0'),
#  Text(0.0530421216848674, 0.275, 'x[0] <= 0.014\nsquared_error = 6.25\nsamples = 2\nvalue = 95.5'),
#  Text(0.0499219968798752, 0.225, 'squared_error = 0.0\nsamples = 1\nvalue = 98.0'),
#  Text(0.056162246489859596, 0.225, 'squared_error = 0.0\nsamples = 1\nvalue = 93.0'),
#  Text(0.0655226209048362, 0.375, 'x[3] <= -0.023\nsquared_error = 358.222\nsamples = 3\nvalue = 121.667'),
#  Text(0.062402496099843996, 0.325, 'x[7] <= -0.058\nsquared_error = 81.0\nsamples = 2\nvalue = 134.0'),
#  Text(0.059282371294851796, 0.275, 'squared_error = 0.0\nsamples = 1\nvalue = 143.0'),
#  Text(0.0655226209048362, 0.275, 'squared_error = 0.0\nsamples = 1\nvalue = 125.0'),
#  Text(0.0686427457098284, 0.325, 'squared_error = 0.0\nsamples = 1\nvalue = 97.0'),
#  Text(0.09516380655226209, 0.425, 'x[4] <= -0.038\nsquared_error = 1322.582\nsamples = 25\nvalue = 103.76'),
#  Text(0.078003120124805, 0.375, 'x[4] <= -0.045\nsquared_error = 769.556\nsamples = 3\nvalue = 171.667'),
#  Text(0.0748829953198128, 0.325, 'squared_error = 0.0\nsamples = 1\nvalue = 134.0'),
#  Text(0.0811232449297972, 0.325, 'x[0] <= -0.056\nsquared_error = 90.25\nsamples = 2\nvalue = 190.5'),
#  Text(0.078003120124805, 0.275, 'squared_error = 0.0\nsamples = 1\nvalue = 200.0'),
#  Text(0.0842433697347894, 0.275, 'squared_error = 0.0\nsamples = 1\nvalue = 181.0'),
#  Text(0.11232449297971919, 0.375, 'x[0] <= -0.029\nsquared_error = 683.432\nsamples = 22\nvalue = 94.5'),
#  Text(0.09828393135725429, 0.325, 'x[3] <= -0.016\nsquared_error = 497.743\nsamples = 12\nvalue = 109.417'),
#  Text(0.0904836193447738, 0.275, 'x[8] <= -0.027\nsquared_error = 351.05\nsamples = 10\nvalue = 115.5'),
#  Text(0.0842433697347894, 0.225, 'x[8] <= -0.029\nsquared_error = 343.265\nsamples = 7\nvalue = 121.857'),
#  Text(0.0811232449297972, 0.175, 'x[0] <= -0.045\nsquared_error = 117.583\nsamples = 6\nvalue = 115.5'),
#  Text(0.078003120124805, 0.125, 'x[2] <= -0.063\nsquared_error = 59.188\nsamples = 4\nvalue = 109.25'),
#  Text(0.0748829953198128, 0.075, 'squared_error = 0.0\nsamples = 1\nvalue = 96.0'),
#  Text(0.0811232449297972, 0.075, 'x[9] <= -0.049\nsquared_error = 0.889\nsamples = 3\nvalue = 113.667'),
#  Text(0.078003120124805, 0.025, 'squared_error = 0.0\nsamples = 1\nvalue = 115.0'),
#  Text(0.0842433697347894, 0.025, 'squared_error = 0.0\nsamples = 2\nvalue = 113.0'),
#  Text(0.0842433697347894, 0.125, 'squared_error = 0.0\nsamples = 2\nvalue = 128.0'),
#  Text(0.0873634945397816, 0.175, 'squared_error = 0.0\nsamples = 1\nvalue = 160.0'),
#  Text(0.0967238689547582, 0.225, 'x[9] <= 0.001\nsquared_error = 54.889\nsamples = 3\nvalue = 100.667'),
#  Text(0.093603744149766, 0.175, 'x[8] <= -0.022\nsquared_error = 2.25\nsamples = 2\nvalue = 95.5'),
#  Text(0.0904836193447738, 0.125, 'squared_error = 0.0\nsamples = 1\nvalue = 94.0'),
#  Text(0.0967238689547582, 0.125, 'squared_error = 0.0\nsamples = 1\nvalue = 97.0'),
#  Text(0.0998439937597504, 0.175, 'squared_error = 0.0\nsamples = 1\nvalue = 111.0'),
#  Text(0.1060842433697348, 0.275, 'x[3] <= -0.011\nsquared_error = 121.0\nsamples = 2\nvalue = 79.0'),
#  Text(0.1029641185647426, 0.225, 'squared_error = 0.0\nsamples = 1\nvalue = 90.0'),
#  Text(0.10920436817472699, 0.225, 'squared_error = 0.0\nsamples = 1\nvalue = 68.0'),
#  Text(0.12636505460218408, 0.325, 'x[9] <= -0.067\nsquared_error = 318.84\nsamples = 10\nvalue = 76.6'),
#  Text(0.11856474258970359, 0.275, 'x[0] <= 0.002\nsquared_error = 30.25\nsamples = 2\nvalue = 57.5'),
#  Text(0.11544461778471139, 0.225, 'squared_error = 0.0\nsamples = 1\nvalue = 52.0'),
#  Text(0.12168486739469579, 0.225, 'squared_error = 0.0\nsamples = 1\nvalue = 63.0'),
#  Text(0.13416536661466458, 0.275, 'x[9] <= 0.003\nsquared_error = 276.984\nsamples = 8\nvalue = 81.375'),
#  Text(0.12792511700468018, 0.225, 'x[6] <= -0.01\nsquared_error = 131.556\nsamples = 6\nvalue = 88.333'),
#  Text(0.12480499219968799, 0.175, 'squared_error = 0.0\nsamples = 1\nvalue = 64.0'),
#  Text(0.1310452418096724, 0.175, 'x[7] <= -0.046\nsquared_error = 15.76\nsamples = 5\nvalue = 93.2'),
#  Text(0.12480499219968799, 0.125, 'x[6] <= 0.1\nsquared_error = 2.25\nsamples = 2\nvalue = 88.5'),
#  Text(0.12168486739469579, 0.075, 'squared_error = 0.0\nsamples = 1\nvalue = 90.0'),
#  Text(0.12792511700468018, 0.075, 'squared_error = 0.0\nsamples = 1\nvalue = 87.0'),
#  Text(0.1372854914196568, 0.125, 'x[4] <= 0.016\nsquared_error = 0.222\nsamples = 3\nvalue = 96.333'),
#  Text(0.13416536661466458, 0.075, 'squared_error = 0.0\nsamples = 2\nvalue = 96.0'),
#  Text(0.14040561622464898, 0.075, 'squared_error = 0.0\nsamples = 1\nvalue = 97.0'),
#  Text(0.14040561622464898, 0.225, 'x[6] <= 0.032\nsquared_error = 132.25\nsamples = 2\nvalue = 60.5'),
#  Text(0.1372854914196568, 0.175, 'squared_error = 0.0\nsamples = 1\nvalue = 49.0'),
#  Text(0.1435257410296412, 0.175, 'squared_error = 0.0\nsamples = 1\nvalue = 72.0'),
#  Text(0.16926677067082682, 0.475, 'x[2] <= -0.076\nsquared_error = 423.275\nsamples = 18\nvalue = 71.944'),
#  Text(0.15912636505460218, 0.425, 'x[4] <= -0.045\nsquared_error = 36.0\nsamples = 2\nvalue = 110.0'),
#  Text(0.15600624024961, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 116.0'),
#  Text(0.1622464898595944, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 104.0'),
#  Text(0.1794071762870515, 0.425, 'x[3] <= -0.012\nsquared_error = 268.027\nsamples = 16\nvalue = 67.188'),
#  Text(0.1684867394695788, 0.375, 'x[5] <= -0.041\nsquared_error = 143.408\nsamples = 14\nvalue = 62.857'),
#  Text(0.15600624024961, 0.325, 'x[0] <= -0.049\nsquared_error = 21.333\nsamples = 6\nvalue = 74.0'),
#  Text(0.1497659906396256, 0.275, 'x[2] <= -0.054\nsquared_error = 0.5\nsamples = 4\nvalue = 71.0'),
#  Text(0.14664586583463338, 0.225, 'squared_error = 0.0\nsamples = 1\nvalue = 70.0'),
#  Text(0.15288611544461778, 0.225, 'x[2] <= -0.044\nsquared_error = 0.222\nsamples = 3\nvalue = 71.333'),
#  Text(0.1497659906396256, 0.175, 'squared_error = 0.0\nsamples = 1\nvalue = 72.0'),
#  Text(0.15600624024961, 0.175, 'squared_error = 0.0\nsamples = 2\nvalue = 71.0'),
#  Text(0.1622464898595944, 0.275, 'x[6] <= 0.058\nsquared_error = 9.0\nsamples = 2\nvalue = 80.0'),
#  Text(0.15912636505460218, 0.225, 'squared_error = 0.0\nsamples = 1\nvalue = 83.0'),
#  Text(0.16536661466458658, 0.225, 'squared_error = 0.0\nsamples = 1\nvalue = 77.0'),
#  Text(0.1809672386895476, 0.325, 'x[8] <= -0.017\nsquared_error = 72.0\nsamples = 8\nvalue = 54.5'),
#  Text(0.1747269890795632, 0.275, 'x[9] <= 0.02\nsquared_error = 28.889\nsamples = 6\nvalue = 50.667'),
#  Text(0.17160686427457097, 0.225, 'x[2] <= -0.025\nsquared_error = 2.0\nsamples = 5\nvalue = 53.0'),
#  Text(0.16536661466458658, 0.175, 'x[8] <= -0.062\nsquared_error = 0.25\nsamples = 2\nvalue = 54.5'),
#  Text(0.1622464898595944, 0.125, 'squared_error = 0.0\nsamples = 1\nvalue = 55.0'),
#  Text(0.1684867394695788, 0.125, 'squared_error = 0.0\nsamples = 1\nvalue = 54.0'),
#  Text(0.17784711388455537, 0.175, 'x[3] <= -0.062\nsquared_error = 0.667\nsamples = 3\nvalue = 52.0'),
#  Text(0.1747269890795632, 0.125, 'squared_error = 0.0\nsamples = 1\nvalue = 51.0'),
#  Text(0.1809672386895476, 0.125, 'x[8] <= -0.053\nsquared_error = 0.25\nsamples = 2\nvalue = 52.5'),
#  Text(0.17784711388455537, 0.075, 'squared_error = 0.0\nsamples = 1\nvalue = 52.0'),
#  Text(0.18408736349453977, 0.075, 'squared_error = 0.0\nsamples = 1\nvalue = 53.0'),
#  Text(0.17784711388455537, 0.225, 'squared_error = 0.0\nsamples = 1\nvalue = 39.0'),
#  Text(0.187207488299532, 0.275, 'x[2] <= -0.017\nsquared_error = 25.0\nsamples = 2\nvalue = 66.0'),
#  Text(0.18408736349453977, 0.225, 'squared_error = 0.0\nsamples = 1\nvalue = 71.0'),
#  Text(0.19032761310452417, 0.225, 'squared_error = 0.0\nsamples = 1\nvalue = 61.0'),
#  Text(0.19032761310452417, 0.375, 'x[5] <= 0.009\nsquared_error = 90.25\nsamples = 2\nvalue = 97.5'),
#  Text(0.187207488299532, 0.325, 'squared_error = 0.0\nsamples = 1\nvalue = 88.0'),
#  Text(0.1934477379095164, 0.325, 'squared_error = 0.0\nsamples = 1\nvalue = 107.0'),
#  Text(0.19500780031201248, 0.525, 'x[4] <= -0.047\nsquared_error = 589.188\nsamples = 4\nvalue = 149.75'),
#  Text(0.18876755070202808, 0.475, 'x[5] <= -0.059\nsquared_error = 25.0\nsamples = 2\nvalue = 173.0'),
#  Text(0.1856474258970359, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 178.0'),
#  Text(0.1918876755070203, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 168.0'),
#  Text(0.20124804992199688, 0.475, 'x[8] <= -0.029\nsquared_error = 72.25\nsamples = 2\nvalue = 126.5'),
#  Text(0.1981279251170047, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 118.0'),
#  Text(0.20436817472698907, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 135.0'),
#  Text(0.22776911076443057, 0.575, 'x[5] <= 0.014\nsquared_error = 885.24\nsamples = 11\nvalue = 64.182'),
#  Text(0.21996879875195008, 0.525, 'x[2] <= -0.053\nsquared_error = 197.432\nsamples = 9\nvalue = 51.889'),
#  Text(0.21372854914196568, 0.475, 'x[4] <= -0.028\nsquared_error = 56.25\nsamples = 2\nvalue = 71.5'),
#  Text(0.21060842433697347, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 64.0'),
#  Text(0.21684867394695787, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 79.0'),
#  Text(0.22620904836193448, 0.475, 'x[5] <= -0.031\nsquared_error = 96.49\nsamples = 7\nvalue = 46.286'),
#  Text(0.22308892355694226, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 25.0'),
#  Text(0.22932917316692666, 0.425, 'x[8] <= -0.037\nsquared_error = 24.472\nsamples = 6\nvalue = 49.833'),
#  Text(0.22620904836193448, 0.375, 'x[4] <= -0.038\nsquared_error = 4.56\nsamples = 5\nvalue = 47.8'),
#  Text(0.22308892355694226, 0.325, 'squared_error = 0.0\nsamples = 1\nvalue = 44.0'),
#  Text(0.22932917316692666, 0.325, 'x[2] <= -0.041\nsquared_error = 1.188\nsamples = 4\nvalue = 48.75'),
#  Text(0.22620904836193448, 0.275, 'squared_error = 0.0\nsamples = 1\nvalue = 47.0'),
#  Text(0.23244929797191888, 0.275, 'x[3] <= 0.025\nsquared_error = 0.222\nsamples = 3\nvalue = 49.333'),
#  Text(0.22932917316692666, 0.225, 'squared_error = 0.0\nsamples = 2\nvalue = 49.0'),
#  Text(0.23556942277691106, 0.225, 'squared_error = 0.0\nsamples = 1\nvalue = 50.0'),
#  Text(0.23244929797191888, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 60.0'),
#  Text(0.23556942277691106, 0.525, 'x[4] <= 0.008\nsquared_error = 240.25\nsamples = 2\nvalue = 119.5'),
#  Text(0.23244929797191888, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 135.0'),
#  Text(0.23868954758190328, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 104.0'),
#  Text(0.19920046801872074, 0.625, 'squared_error = 0.0\nsamples = 1\nvalue = 200.0'),
#  Text(0.27262090483619345, 0.675, 'x[5] <= -0.029\nsquared_error = 3316.454\nsamples = 19\nvalue = 113.421'),
#  Text(0.2574102964118565, 0.625, 'x[0] <= -0.04\nsquared_error = 1412.96\nsamples = 5\nvalue = 185.8'),
#  Text(0.2542901716068643, 0.575, 'x[3] <= -0.05\nsquared_error = 396.688\nsamples = 4\nvalue = 169.25'),
#  Text(0.24804992199687986, 0.525, 'x[5] <= -0.05\nsquared_error = 121.0\nsamples = 2\nvalue = 151.0'),
#  Text(0.24492979719188768, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 140.0'),
#  Text(0.25117004680187205, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 162.0'),
#  Text(0.26053042121684866, 0.525, 'x[3] <= -0.026\nsquared_error = 6.25\nsamples = 2\nvalue = 187.5'),
#  Text(0.2574102964118565, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 190.0'),
#  Text(0.26365054602184085, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 185.0'),
#  Text(0.26053042121684866, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 252.0'),
#  Text(0.2878315132605304, 0.625, 'x[8] <= -0.007\nsquared_error = 1457.102\nsamples = 14\nvalue = 87.571'),
#  Text(0.28471138845553823, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 168.0'),
#  Text(0.2909516380655226, 0.575, 'x[0] <= -0.007\nsquared_error = 1033.314\nsamples = 13\nvalue = 81.385'),
#  Text(0.27769110764430577, 0.525, 'x[0] <= -0.024\nsquared_error = 248.98\nsamples = 7\nvalue = 62.143'),
#  Text(0.2698907956318253, 0.475, 'x[7] <= -0.028\nsquared_error = 180.4\nsamples = 5\nvalue = 69.0'),
#  Text(0.26365054602184085, 0.425, 'x[6] <= 0.113\nsquared_error = 9.0\nsamples = 2\nvalue = 60.0'),
#  Text(0.26053042121684866, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 63.0'),
#  Text(0.2667706708268331, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 57.0'),
#  Text(0.27613104524180965, 0.425, 'x[9] <= -0.014\nsquared_error = 204.667\nsamples = 3\nvalue = 75.0'),
#  Text(0.27301092043681746, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 93.0'),
#  Text(0.2792511700468019, 0.375, 'x[8] <= 0.017\nsquared_error = 64.0\nsamples = 2\nvalue = 66.0'),
#  Text(0.27613104524180965, 0.325, 'squared_error = 0.0\nsamples = 1\nvalue = 74.0'),
#  Text(0.2823712948517941, 0.325, 'squared_error = 0.0\nsamples = 1\nvalue = 58.0'),
#  Text(0.28549141965678626, 0.475, 'x[6] <= 0.021\nsquared_error = 9.0\nsamples = 2\nvalue = 45.0'),
#  Text(0.2823712948517941, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 42.0'),
#  Text(0.28861154446177845, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 48.0'),
#  Text(0.3042121684867395, 0.525, 'x[8] <= 0.001\nsquared_error = 1012.472\nsamples = 6\nvalue = 103.833'),
#  Text(0.29797191887675506, 0.475, 'x[4] <= 0.034\nsquared_error = 36.0\nsamples = 2\nvalue = 147.0'),
#  Text(0.2948517940717629, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 153.0'),
#  Text(0.30109204368174725, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 141.0'),
#  Text(0.31045241809672386, 0.475, 'x[1] <= 0.003\nsquared_error = 103.188\nsamples = 4\nvalue = 82.25'),
#  Text(0.3073322932917317, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 66.0'),
#  Text(0.31357254290171604, 0.425, 'x[4] <= 0.003\nsquared_error = 20.222\nsamples = 3\nvalue = 87.667'),
#  Text(0.31045241809672386, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 94.0'),
#  Text(0.3166926677067083, 0.375, 'x[5] <= 0.03\nsquared_error = 0.25\nsamples = 2\nvalue = 84.5'),
#  Text(0.31357254290171604, 0.325, 'squared_error = 0.0\nsamples = 1\nvalue = 85.0'),
#  Text(0.31981279251170047, 0.325, 'squared_error = 0.0\nsamples = 1\nvalue = 84.0'),
#  Text(0.24059087363494538, 0.725, 'squared_error = 0.0\nsamples = 1\nvalue = 216.0'),
#  Text(0.3640795631825273, 0.775, 'x[5] <= -0.02\nsquared_error = 2005.757\nsamples = 29\nvalue = 125.034'),
#  Text(0.3291731669266771, 0.725, 'x[2] <= -0.035\nsquared_error = 1688.551\nsamples = 14\nvalue = 150.857'),
#  Text(0.31357254290171604, 0.675, 'x[2] <= -0.057\nsquared_error = 1300.25\nsamples = 4\nvalue = 109.5'),
#  Text(0.31045241809672386, 0.625, 'squared_error = 0.0\nsamples = 1\nvalue = 170.0'),
#  Text(0.3166926677067083, 0.625, 'x[4] <= -0.004\nsquared_error = 106.889\nsamples = 3\nvalue = 89.333'),
#  Text(0.31357254290171604, 0.575, 'x[4] <= -0.046\nsquared_error = 20.25\nsamples = 2\nvalue = 82.5'),
#  Text(0.31045241809672386, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 78.0'),
#  Text(0.3166926677067083, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 87.0'),
#  Text(0.31981279251170047, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 103.0'),
#  Text(0.34477379095163807, 0.675, 'x[8] <= -0.014\nsquared_error = 886.04\nsamples = 10\nvalue = 167.4'),
#  Text(0.33229329173166927, 0.625, 'x[2] <= -0.013\nsquared_error = 461.2\nsamples = 5\nvalue = 191.0'),
#  Text(0.32605304212168484, 0.575, 'x[3] <= 0.027\nsquared_error = 84.667\nsamples = 3\nvalue = 206.0'),
#  Text(0.32293291731669266, 0.525, 'x[8] <= -0.029\nsquared_error = 0.25\nsamples = 2\nvalue = 199.5'),
#  Text(0.31981279251170047, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 199.0'),
#  Text(0.32605304212168484, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 200.0'),
#  Text(0.3291731669266771, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 219.0'),
#  Text(0.33853354134165364, 0.575, 'x[3] <= 0.022\nsquared_error = 182.25\nsamples = 2\nvalue = 168.5'),
#  Text(0.33541341653666146, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 155.0'),
#  Text(0.3416536661466459, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 182.0'),
#  Text(0.35725429017160687, 0.625, 'x[0] <= 0.047\nsquared_error = 196.96\nsamples = 5\nvalue = 143.8'),
#  Text(0.35101404056162244, 0.575, 'x[1] <= 0.003\nsquared_error = 24.889\nsamples = 3\nvalue = 154.667'),
#  Text(0.34789391575663026, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 148.0'),
#  Text(0.3541341653666147, 0.525, 'x[8] <= -0.005\nsquared_error = 4.0\nsamples = 2\nvalue = 158.0'),
#  Text(0.35101404056162244, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 160.0'),
#  Text(0.35725429017160687, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 156.0'),
#  Text(0.36349453978159124, 0.575, 'x[1] <= 0.003\nsquared_error = 12.25\nsamples = 2\nvalue = 127.5'),
#  Text(0.36037441497659906, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 131.0'),
#  Text(0.3666146645865835, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 124.0'),
#  Text(0.39898595943837756, 0.725, 'x[9] <= 0.032\nsquared_error = 1098.596\nsamples = 15\nvalue = 100.933'),
#  Text(0.38923556942277693, 0.675, 'x[2] <= -0.033\nsquared_error = 467.136\nsamples = 13\nvalue = 90.692'),
#  Text(0.3790951638065523, 0.625, 'x[8] <= -0.025\nsquared_error = 74.688\nsamples = 4\nvalue = 67.75'),
#  Text(0.37597503900156004, 0.575, 'x[0] <= 0.062\nsquared_error = 2.889\nsamples = 3\nvalue = 72.667'),
#  Text(0.37285491419656785, 0.525, 'x[3] <= -0.003\nsquared_error = 0.25\nsamples = 2\nvalue = 71.5'),
#  Text(0.36973478939157567, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 72.0'),
#  Text(0.37597503900156004, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 71.0'),
#  Text(0.3790951638065523, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 75.0'),
#  Text(0.38221528861154447, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 53.0'),
#  Text(0.3993759750390016, 0.625, 'x[5] <= 0.015\nsquared_error = 303.654\nsamples = 9\nvalue = 100.889'),
#  Text(0.3915756630265211, 0.575, 'x[3] <= -0.015\nsquared_error = 176.204\nsamples = 7\nvalue = 107.714'),
#  Text(0.38533541341653665, 0.525, 'x[5] <= -0.008\nsquared_error = 33.556\nsamples = 3\nvalue = 95.667'),
#  Text(0.38221528861154447, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 88.0'),
#  Text(0.38845553822152884, 0.475, 'x[3] <= -0.033\nsquared_error = 6.25\nsamples = 2\nvalue = 99.5'),
#  Text(0.38533541341653665, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 102.0'),
#  Text(0.3915756630265211, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 97.0'),
#  Text(0.39781591263650545, 0.525, 'x[8] <= -0.043\nsquared_error = 92.688\nsamples = 4\nvalue = 116.75'),
#  Text(0.39469578783151327, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 132.0'),
#  Text(0.40093603744149764, 0.475, 'x[1] <= 0.003\nsquared_error = 20.222\nsamples = 3\nvalue = 111.667'),
#  Text(0.39781591263650545, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 118.0'),
#  Text(0.4040561622464899, 0.425, 'x[9] <= -0.045\nsquared_error = 0.25\nsamples = 2\nvalue = 108.5'),
#  Text(0.40093603744149764, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 109.0'),
#  Text(0.40717628705148207, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 108.0'),
#  Text(0.40717628705148207, 0.575, 'x[9] <= -0.005\nsquared_error = 16.0\nsamples = 2\nvalue = 77.0'),
#  Text(0.4040561622464899, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 81.0'),
#  Text(0.41029641185647425, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 73.0'),
#  Text(0.40873634945397813, 0.675, 'x[8] <= -0.029\nsquared_error = 90.25\nsamples = 2\nvalue = 167.5'),
#  Text(0.40561622464898595, 0.625, 'squared_error = 0.0\nsamples = 1\nvalue = 177.0'),
#  Text(0.4118564742589704, 0.625, 'squared_error = 0.0\nsamples = 1\nvalue = 158.0'),
#  Text(0.4426677067082683, 0.825, 'x[8] <= 0.006\nsquared_error = 2984.15\nsamples = 21\nvalue = 147.571'),
#  Text(0.42589703588143524, 0.775, 'x[1] <= 0.003\nsquared_error = 985.2\nsamples = 10\nvalue = 113.0'),
#  Text(0.41965678627145087, 0.725, 'x[8] <= -0.022\nsquared_error = 342.25\nsamples = 2\nvalue = 164.5'),
#  Text(0.4165366614664587, 0.675, 'squared_error = 0.0\nsamples = 1\nvalue = 146.0'),
#  Text(0.42277691107644305, 0.675, 'squared_error = 0.0\nsamples = 1\nvalue = 183.0'),
#  Text(0.43213728549141966, 0.725, 'x[2] <= -0.008\nsquared_error = 317.109\nsamples = 8\nvalue = 100.125'),
#  Text(0.4290171606864275, 0.675, 'x[6] <= -0.062\nsquared_error = 115.673\nsamples = 7\nvalue = 94.571'),
#  Text(0.42277691107644305, 0.625, 'x[8] <= -0.025\nsquared_error = 29.556\nsamples = 3\nvalue = 84.667'),
#  Text(0.41965678627145087, 0.575, 'x[0] <= 0.04\nsquared_error = 0.25\nsamples = 2\nvalue = 88.5'),
#  Text(0.4165366614664587, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 88.0'),
#  Text(0.42277691107644305, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 89.0'),
#  Text(0.42589703588143524, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 77.0'),
#  Text(0.43525741029641185, 0.625, 'x[2] <= -0.014\nsquared_error = 51.5\nsamples = 4\nvalue = 102.0'),
#  Text(0.43213728549141966, 0.575, 'x[6] <= -0.018\nsquared_error = 14.889\nsamples = 3\nvalue = 105.667'),
#  Text(0.4290171606864275, 0.525, 'x[2] <= -0.026\nsquared_error = 1.0\nsamples = 2\nvalue = 103.0'),
#  Text(0.42589703588143524, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 102.0'),
#  Text(0.43213728549141966, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 104.0'),
#  Text(0.43525741029641185, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 111.0'),
#  Text(0.43837753510140404, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 91.0'),
#  Text(0.43525741029641185, 0.675, 'squared_error = 0.0\nsamples = 1\nvalue = 139.0'),
#  Text(0.4594383775351014, 0.775, 'x[5] <= 0.005\nsquared_error = 2727.091\nsamples = 11\nvalue = 179.0'),
#  Text(0.44773790951638065, 0.725, 'x[8] <= 0.017\nsquared_error = 738.889\nsamples = 3\nvalue = 240.333'),
#  Text(0.44461778471138846, 0.675, 'x[4] <= -0.023\nsquared_error = 6.25\nsamples = 2\nvalue = 259.5'),
#  Text(0.4414976599063963, 0.625, 'squared_error = 0.0\nsamples = 1\nvalue = 257.0'),
#  Text(0.44773790951638065, 0.625, 'squared_error = 0.0\nsamples = 1\nvalue = 262.0'),
#  Text(0.45085803432137284, 0.675, 'squared_error = 0.0\nsamples = 1\nvalue = 202.0'),
#  Text(0.4711388455538221, 0.725, 'x[2] <= -0.009\nsquared_error = 1533.0\nsamples = 8\nvalue = 156.0'),
#  Text(0.46021840873634945, 0.675, 'x[9] <= -0.011\nsquared_error = 502.64\nsamples = 5\nvalue = 182.4'),
#  Text(0.4539781591263651, 0.625, 'x[6] <= -0.029\nsquared_error = 49.0\nsamples = 2\nvalue = 207.0'),
#  Text(0.45085803432137284, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 214.0'),
#  Text(0.45709828393135726, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 200.0'),
#  Text(0.4664586583463339, 0.625, 'x[9] <= 0.018\nsquared_error = 132.667\nsamples = 3\nvalue = 166.0'),
#  Text(0.46333853354134164, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 151.0'),
#  Text(0.46957878315132606, 0.575, 'x[0] <= 0.027\nsquared_error = 30.25\nsamples = 2\nvalue = 173.5'),
#  Text(0.4664586583463339, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 179.0'),
#  Text(0.47269890795631825, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 168.0'),
#  Text(0.48205928237129486, 0.675, 'x[3] <= 0.053\nsquared_error = 152.667\nsamples = 3\nvalue = 112.0'),
#  Text(0.4789391575663027, 0.625, 'x[4] <= 0.022\nsquared_error = 12.25\nsamples = 2\nvalue = 103.5'),
#  Text(0.47581903276131043, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 107.0'),
#  Text(0.48205928237129486, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 100.0'),
#  Text(0.48517940717628705, 0.625, 'squared_error = 0.0\nsamples = 1\nvalue = 129.0'),
#  Text(0.5691790171606864, 0.875, 'x[3] <= 0.017\nsquared_error = 5372.564\nsamples = 57\nvalue = 164.544'),
#  Text(0.5059477379095164, 0.825, 'x[0] <= -0.08\nsquared_error = 2445.151\nsamples = 35\nvalue = 136.857'),
#  Text(0.5028276131045242, 0.775, 'squared_error = 0.0\nsamples = 1\nvalue = 246.0'),
#  Text(0.5090678627145085, 0.775, 'x[2] <= 0.006\nsquared_error = 2156.405\nsamples = 34\nvalue = 133.647'),
#  Text(0.4914196567862715, 0.725, 'x[0] <= -0.033\nsquared_error = 12.25\nsamples = 2\nvalue = 63.5'),
#  Text(0.48829953198127923, 0.675, 'squared_error = 0.0\nsamples = 1\nvalue = 67.0'),
#  Text(0.49453978159126366, 0.675, 'squared_error = 0.0\nsamples = 1\nvalue = 60.0'),
#  Text(0.5267160686427457, 0.725, 'x[4] <= -0.048\nsquared_error = 1963.655\nsamples = 32\nvalue = 138.031'),
#  Text(0.500780031201248, 0.675, 'x[3] <= -0.045\nsquared_error = 782.222\nsamples = 6\nvalue = 176.333'),
#  Text(0.4914196567862715, 0.625, 'x[5] <= -0.06\nsquared_error = 136.222\nsamples = 3\nvalue = 197.667'),
#  Text(0.48829953198127923, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 182.0'),
#  Text(0.49453978159126366, 0.575, 'x[8] <= -0.06\nsquared_error = 20.25\nsamples = 2\nvalue = 205.5'),
#  Text(0.4914196567862715, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 201.0'),
#  Text(0.49765990639625585, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 210.0'),
#  Text(0.5101404056162246, 0.625, 'x[6] <= 0.021\nsquared_error = 518.0\nsamples = 3\nvalue = 155.0'),
#  Text(0.5070202808112324, 0.575, 'x[9] <= -0.042\nsquared_error = 9.0\nsamples = 2\nvalue = 139.0'),
#  Text(0.5039001560062403, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 142.0'),
#  Text(0.5101404056162246, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 136.0'),
#  Text(0.5132605304212169, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 187.0'),
#  Text(0.5526521060842434, 0.675, 'x[4] <= 0.016\nsquared_error = 1819.617\nsamples = 26\nvalue = 129.192'),
#  Text(0.5343213728549142, 0.625, 'x[9] <= 0.024\nsquared_error = 1104.131\nsamples = 17\nvalue = 113.529'),
#  Text(0.531201248049922, 0.575, 'x[9] <= 0.001\nsquared_error = 983.277\nsamples = 16\nvalue = 110.188'),
#  Text(0.516380655226209, 0.525, 'x[9] <= -0.032\nsquared_error = 865.65\nsamples = 10\nvalue = 120.5'),
#  Text(0.5054602184087363, 0.475, 'x[3] <= -0.001\nsquared_error = 555.04\nsamples = 5\nvalue = 99.6'),
#  Text(0.5023400936037441, 0.425, 'x[2] <= 0.027\nsquared_error = 158.188\nsamples = 4\nvalue = 89.25'),
#  Text(0.49921996879875197, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 69.0'),
#  Text(0.5054602184087363, 0.375, 'x[4] <= -0.006\nsquared_error = 28.667\nsamples = 3\nvalue = 96.0'),
#  Text(0.5023400936037441, 0.325, 'x[0] <= 0.02\nsquared_error = 6.25\nsamples = 2\nvalue = 92.5'),
#  Text(0.49921996879875197, 0.275, 'squared_error = 0.0\nsamples = 1\nvalue = 95.0'),
#  Text(0.5054602184087363, 0.275, 'squared_error = 0.0\nsamples = 1\nvalue = 90.0'),
#  Text(0.5085803432137286, 0.325, 'squared_error = 0.0\nsamples = 1\nvalue = 103.0'),
#  Text(0.5085803432137286, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 141.0'),
#  Text(0.5273010920436817, 0.475, 'x[9] <= -0.003\nsquared_error = 302.64\nsamples = 5\nvalue = 141.4'),
#  Text(0.5241809672386896, 0.425, 'x[7] <= -0.021\nsquared_error = 85.688\nsamples = 4\nvalue = 133.75'),
#  Text(0.5179407176287052, 0.375, 'x[9] <= -0.011\nsquared_error = 16.0\nsamples = 2\nvalue = 125.0'),
#  Text(0.514820592823713, 0.325, 'squared_error = 0.0\nsamples = 1\nvalue = 121.0'),
#  Text(0.5210608424336973, 0.325, 'squared_error = 0.0\nsamples = 1\nvalue = 129.0'),
#  Text(0.5304212168486739, 0.375, 'x[1] <= 0.003\nsquared_error = 2.25\nsamples = 2\nvalue = 142.5'),
#  Text(0.5273010920436817, 0.325, 'squared_error = 0.0\nsamples = 1\nvalue = 144.0'),
#  Text(0.5335413416536662, 0.325, 'squared_error = 0.0\nsamples = 1\nvalue = 141.0'),
#  Text(0.5304212168486739, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 172.0'),
#  Text(0.5460218408736349, 0.525, 'x[6] <= -0.021\nsquared_error = 706.667\nsamples = 6\nvalue = 93.0'),
#  Text(0.5397815912636506, 0.475, 'x[9] <= 0.015\nsquared_error = 225.0\nsamples = 2\nvalue = 125.0'),
#  Text(0.5366614664586583, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 110.0'),
#  Text(0.5429017160686428, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 140.0'),
#  Text(0.5522620904836193, 0.475, 'x[8] <= -0.024\nsquared_error = 179.5\nsamples = 4\nvalue = 77.0'),
#  Text(0.5491419656786272, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 55.0'),
#  Text(0.5553822152886115, 0.425, 'x[1] <= 0.003\nsquared_error = 24.222\nsamples = 3\nvalue = 84.333'),
#  Text(0.5522620904836193, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 78.0'),
#  Text(0.5585023400936038, 0.375, 'x[6] <= -0.001\nsquared_error = 6.25\nsamples = 2\nvalue = 87.5'),
#  Text(0.5553822152886115, 0.325, 'squared_error = 0.0\nsamples = 1\nvalue = 90.0'),
#  Text(0.5616224648985959, 0.325, 'squared_error = 0.0\nsamples = 1\nvalue = 85.0'),
#  Text(0.5374414976599063, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 167.0'),
#  Text(0.5709828393135725, 0.625, 'x[6] <= -0.06\nsquared_error = 1832.395\nsamples = 9\nvalue = 158.778'),
#  Text(0.5678627145085804, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 84.0'),
#  Text(0.5741029641185648, 0.575, 'x[0] <= -0.055\nsquared_error = 1275.109\nsamples = 8\nvalue = 168.125'),
#  Text(0.5709828393135725, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 96.0'),
#  Text(0.5772230889235569, 0.525, 'x[3] <= 0.013\nsquared_error = 607.959\nsamples = 7\nvalue = 178.429'),
#  Text(0.5741029641185648, 0.475, 'x[9] <= 0.005\nsquared_error = 90.139\nsamples = 6\nvalue = 187.833'),
#  Text(0.5678627145085804, 0.425, 'x[0] <= 0.031\nsquared_error = 0.667\nsamples = 3\nvalue = 197.0'),
#  Text(0.5647425897035881, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 196.0'),
#  Text(0.5709828393135725, 0.375, 'x[2] <= 0.031\nsquared_error = 0.25\nsamples = 2\nvalue = 197.5'),
#  Text(0.5678627145085804, 0.325, 'squared_error = 0.0\nsamples = 1\nvalue = 197.0'),
#  Text(0.5741029641185648, 0.325, 'squared_error = 0.0\nsamples = 1\nvalue = 198.0'),
#  Text(0.5803432137285491, 0.425, 'x[6] <= -0.04\nsquared_error = 11.556\nsamples = 3\nvalue = 178.667'),
#  Text(0.5772230889235569, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 174.0'),
#  Text(0.5834633385335414, 0.375, 'x[3] <= -0.025\nsquared_error = 1.0\nsamples = 2\nvalue = 181.0'),
#  Text(0.5803432137285491, 0.325, 'squared_error = 0.0\nsamples = 1\nvalue = 180.0'),
#  Text(0.5865834633385335, 0.325, 'squared_error = 0.0\nsamples = 1\nvalue = 182.0'),
#  Text(0.5803432137285491, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 122.0'),
#  Text(0.6324102964118564, 0.825, 'x[2] <= 0.066\nsquared_error = 6870.151\nsamples = 22\nvalue = 208.591'),
#  Text(0.6033541341653667, 0.775, 'x[7] <= -0.018\nsquared_error = 5796.173\nsamples = 18\nvalue = 187.778'),
#  Text(0.5834633385335414, 0.725, 'x[8] <= -0.007\nsquared_error = 566.0\nsamples = 3\nvalue = 77.0'),
#  Text(0.5803432137285491, 0.675, 'x[0] <= 0.054\nsquared_error = 81.0\nsamples = 2\nvalue = 61.0'),
#  Text(0.5772230889235569, 0.625, 'squared_error = 0.0\nsamples = 1\nvalue = 52.0'),
#  Text(0.5834633385335414, 0.625, 'squared_error = 0.0\nsamples = 1\nvalue = 70.0'),
#  Text(0.5865834633385335, 0.675, 'squared_error = 0.0\nsamples = 1\nvalue = 109.0'),
#  Text(0.6232449297971919, 0.725, 'x[6] <= -0.027\nsquared_error = 3896.996\nsamples = 15\nvalue = 209.933'),
#  Text(0.6006240249609984, 0.675, 'x[6] <= -0.045\nsquared_error = 2814.248\nsamples = 11\nvalue = 185.455'),
#  Text(0.5897035881435257, 0.625, 'x[5] <= 0.019\nsquared_error = 441.0\nsamples = 2\nvalue = 256.0'),
#  Text(0.5865834633385335, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 277.0'),
#  Text(0.592823712948518, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 235.0'),
#  Text(0.6115444617784711, 0.625, 'x[6] <= -0.038\nsquared_error = 1989.951\nsamples = 9\nvalue = 169.778'),
#  Text(0.5990639625585024, 0.575, 'x[9] <= -0.001\nsquared_error = 152.25\nsamples = 4\nvalue = 133.5'),
#  Text(0.592823712948518, 0.525, 'x[0] <= 0.042\nsquared_error = 42.25\nsamples = 2\nvalue = 144.5'),
#  Text(0.5897035881435257, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 151.0'),
#  Text(0.5959438377535101, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 138.0'),
#  Text(0.6053042121684867, 0.525, 'x[4] <= -0.037\nsquared_error = 20.25\nsamples = 2\nvalue = 122.5'),
#  Text(0.6021840873634945, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 127.0'),
#  Text(0.608424336973479, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 118.0'),
#  Text(0.62402496099844, 0.575, 'x[5] <= 0.01\nsquared_error = 1564.96\nsamples = 5\nvalue = 198.8'),
#  Text(0.6177847113884556, 0.525, 'x[6] <= -0.031\nsquared_error = 361.0\nsamples = 2\nvalue = 244.0'),
#  Text(0.6146645865834633, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 263.0'),
#  Text(0.6209048361934477, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 225.0'),
#  Text(0.6302652106084243, 0.525, 'x[6] <= -0.031\nsquared_error = 97.556\nsamples = 3\nvalue = 168.667'),
#  Text(0.6271450858034321, 0.475, 'x[8] <= -0.002\nsquared_error = 6.25\nsamples = 2\nvalue = 175.5'),
#  Text(0.62402496099844, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 178.0'),
#  Text(0.6302652106084243, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 173.0'),
#  Text(0.6333853354134166, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 155.0'),
#  Text(0.6458658346333853, 0.675, 'x[5] <= 0.022\nsquared_error = 695.188\nsamples = 4\nvalue = 277.25'),
#  Text(0.6427457098283932, 0.625, 'x[5] <= 0.002\nsquared_error = 206.889\nsamples = 3\nvalue = 290.667'),
#  Text(0.6396255850234009, 0.575, 'x[8] <= 0.015\nsquared_error = 0.25\nsamples = 2\nvalue = 280.5'),
#  Text(0.6365054602184087, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 281.0'),
#  Text(0.6427457098283932, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 280.0'),
#  Text(0.6458658346333853, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 311.0'),
#  Text(0.6489859594383776, 0.625, 'squared_error = 0.0\nsamples = 1\nvalue = 237.0'),
#  Text(0.6614664586583463, 0.775, 'x[9] <= 0.009\nsquared_error = 981.688\nsamples = 4\nvalue = 302.25'),
#  Text(0.6552262090483619, 0.725, 'x[4] <= -0.034\nsquared_error = 210.25\nsamples = 2\nvalue = 273.5'),
#  Text(0.6521060842433697, 0.675, 'squared_error = 0.0\nsamples = 1\nvalue = 288.0'),
#  Text(0.6583463338533542, 0.675, 'squared_error = 0.0\nsamples = 1\nvalue = 259.0'),
#  Text(0.6677067082683308, 0.725, 'x[6] <= -0.064\nsquared_error = 100.0\nsamples = 2\nvalue = 331.0'),
#  Text(0.6645865834633385, 0.675, 'squared_error = 0.0\nsamples = 1\nvalue = 341.0'),
#  Text(0.6708268330733229, 0.675, 'squared_error = 0.0\nsamples = 1\nvalue = 321.0'),
#  Text(0.875560647425897, 0.925, 'x[2] <= 0.056\nsquared_error = 4163.865\nsamples = 104\nvalue = 210.481'),
#  Text(0.7742830416341653, 0.95, '  False'),
#  Text(0.7936329953198128, 0.875, 'x[9] <= 0.034\nsquared_error = 3463.866\nsamples = 76\nvalue = 192.947'),
#  Text(0.7076833073322933, 0.825, 'x[3] <= -0.038\nsquared_error = 3196.908\nsamples = 52\nvalue = 178.769'),
#  Text(0.6864274570982839, 0.775, 'x[8] <= 0.044\nsquared_error = 371.44\nsamples = 5\nvalue = 94.4'),
#  Text(0.6801872074882995, 0.725, 'x[9] <= 0.018\nsquared_error = 93.556\nsamples = 3\nvalue = 108.667'),
#  Text(0.6770670826833073, 0.675, 'squared_error = 0.0\nsamples = 1\nvalue = 95.0'),
#  Text(0.6833073322932918, 0.675, 'x[8] <= 0.031\nsquared_error = 0.25\nsamples = 2\nvalue = 115.5'),
#  Text(0.6801872074882995, 0.625, 'squared_error = 0.0\nsamples = 1\nvalue = 115.0'),
#  Text(0.6864274570982839, 0.625, 'squared_error = 0.0\nsamples = 1\nvalue = 116.0'),
#  Text(0.6926677067082684, 0.725, 'x[8] <= 0.053\nsquared_error = 25.0\nsamples = 2\nvalue = 73.0'),
#  Text(0.6895475819032761, 0.675, 'squared_error = 0.0\nsamples = 1\nvalue = 78.0'),
#  Text(0.6957878315132605, 0.675, 'squared_error = 0.0\nsamples = 1\nvalue = 68.0'),
#  Text(0.7289391575663027, 0.775, 'x[2] <= -0.036\nsquared_error = 2659.679\nsamples = 47\nvalue = 187.745'),
#  Text(0.7051482059282371, 0.725, 'x[0] <= -0.006\nsquared_error = 90.25\nsamples = 2\nvalue = 99.5'),
#  Text(0.7020280811232449, 0.675, 'squared_error = 0.0\nsamples = 1\nvalue = 109.0'),
#  Text(0.7082683307332294, 0.675, 'squared_error = 0.0\nsamples = 1\nvalue = 90.0'),
#  Text(0.7527301092043682, 0.725, 'x[3] <= -0.022\nsquared_error = 2412.4\nsamples = 45\nvalue = 191.667'),
#  Text(0.7145085803432137, 0.675, 'x[9] <= -0.011\nsquared_error = 1673.44\nsamples = 5\nvalue = 239.4'),
#  Text(0.7082683307332294, 0.625, 'x[5] <= -0.028\nsquared_error = 676.0\nsamples = 2\nvalue = 284.0'),
#  Text(0.7051482059282371, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 310.0'),
#  Text(0.7113884555382215, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 258.0'),
#  Text(0.7207488299531981, 0.625, 'x[8] <= 0.054\nsquared_error = 128.222\nsamples = 3\nvalue = 209.667'),
#  Text(0.717628705148206, 0.575, 'x[0] <= -0.018\nsquared_error = 16.0\nsamples = 2\nvalue = 202.0'),
#  Text(0.7145085803432137, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 206.0'),
#  Text(0.7207488299531981, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 198.0'),
#  Text(0.7238689547581904, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 225.0'),
#  Text(0.7909516380655226, 0.675, 'x[0] <= 0.009\nsquared_error = 2184.36\nsamples = 40\nvalue = 185.7'),
#  Text(0.7515600624024961, 0.625, 'x[4] <= -0.008\nsquared_error = 1631.139\nsamples = 18\nvalue = 163.5'),
#  Text(0.7301092043681747, 0.575, 'x[2] <= 0.048\nsquared_error = 1840.806\nsamples = 6\nvalue = 139.167'),
#  Text(0.7269890795631825, 0.525, 'x[4] <= -0.026\nsquared_error = 601.76\nsamples = 5\nvalue = 122.8'),
#  Text(0.7238689547581904, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 161.0'),
#  Text(0.7301092043681747, 0.475, 'x[5] <= 0.001\nsquared_error = 296.188\nsamples = 4\nvalue = 113.25'),
#  Text(0.7269890795631825, 0.425, 'x[8] <= 0.044\nsquared_error = 27.556\nsamples = 3\nvalue = 103.667'),
#  Text(0.7238689547581904, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 111.0'),
#  Text(0.7301092043681747, 0.375, 'x[1] <= 0.003\nsquared_error = 1.0\nsamples = 2\nvalue = 100.0'),
#  Text(0.7269890795631825, 0.325, 'squared_error = 0.0\nsamples = 1\nvalue = 99.0'),
#  Text(0.733229329173167, 0.325, 'squared_error = 0.0\nsamples = 1\nvalue = 101.0'),
#  Text(0.733229329173167, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 142.0'),
#  Text(0.733229329173167, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 221.0'),
#  Text(0.7730109204368175, 0.575, 'x[5] <= 0.057\nsquared_error = 1082.222\nsamples = 12\nvalue = 175.667'),
#  Text(0.7535101404056163, 0.525, 'x[5] <= -0.004\nsquared_error = 694.857\nsamples = 7\nvalue = 194.0'),
#  Text(0.7425897035881436, 0.475, 'x[3] <= 0.029\nsquared_error = 182.889\nsamples = 3\nvalue = 167.667'),
#  Text(0.7394695787831513, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 185.0'),
#  Text(0.7457098283931357, 0.425, 'x[5] <= -0.02\nsquared_error = 49.0\nsamples = 2\nvalue = 159.0'),
#  Text(0.7425897035881436, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 166.0'),
#  Text(0.748829953198128, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 152.0'),
#  Text(0.7644305772230889, 0.475, 'x[9] <= -0.007\nsquared_error = 168.688\nsamples = 4\nvalue = 213.75'),
#  Text(0.7581903276131046, 0.425, 'x[5] <= 0.022\nsquared_error = 49.0\nsamples = 2\nvalue = 202.0'),
#  Text(0.7550702028081123, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 195.0'),
#  Text(0.7613104524180967, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 209.0'),
#  Text(0.7706708268330733, 0.425, 'x[6] <= -0.043\nsquared_error = 12.25\nsamples = 2\nvalue = 225.5'),
#  Text(0.7675507020280812, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 229.0'),
#  Text(0.7737909516380655, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 222.0'),
#  Text(0.7925117004680188, 0.525, 'x[3] <= 0.044\nsquared_error = 495.2\nsamples = 5\nvalue = 150.0'),
#  Text(0.7862714508580343, 0.475, 'x[6] <= -0.019\nsquared_error = 57.556\nsamples = 3\nvalue = 132.667'),
#  Text(0.7831513260530422, 0.425, 'x[0] <= -0.038\nsquared_error = 1.0\nsamples = 2\nvalue = 138.0'),
#  Text(0.7800312012480499, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 137.0'),
#  Text(0.7862714508580343, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 139.0'),
#  Text(0.7893915756630265, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 122.0'),
#  Text(0.7987519500780031, 0.475, 'x[9] <= -0.024\nsquared_error = 25.0\nsamples = 2\nvalue = 176.0'),
#  Text(0.7956318252730109, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 171.0'),
#  Text(0.8018720748829953, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 181.0'),
#  Text(0.8303432137285491, 0.625, 'x[0] <= 0.04\nsquared_error = 1903.845\nsamples = 22\nvalue = 203.864'),
#  Text(0.8143525741029641, 0.575, 'x[4] <= -0.011\nsquared_error = 1069.44\nsamples = 10\nvalue = 230.6'),
#  Text(0.8081123244929798, 0.525, 'x[8] <= 0.046\nsquared_error = 484.0\nsamples = 2\nvalue = 186.0'),
#  Text(0.8049921996879875, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 164.0'),
#  Text(0.8112324492979719, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 208.0'),
#  Text(0.8205928237129485, 0.525, 'x[2] <= 0.028\nsquared_error = 594.188\nsamples = 8\nvalue = 241.75'),
#  Text(0.8174726989079563, 0.475, 'x[0] <= 0.036\nsquared_error = 366.571\nsamples = 7\nvalue = 248.0'),
#  Text(0.8143525741029641, 0.425, 'x[3] <= 0.032\nsquared_error = 175.667\nsamples = 6\nvalue = 254.0'),
#  Text(0.8081123244929798, 0.375, 'x[2] <= -0.01\nsquared_error = 86.75\nsamples = 4\nvalue = 246.5'),
#  Text(0.8049921996879875, 0.325, 'squared_error = 0.0\nsamples = 1\nvalue = 233.0'),
#  Text(0.8112324492979719, 0.325, 'x[6] <= -0.042\nsquared_error = 34.667\nsamples = 3\nvalue = 251.0'),
#  Text(0.8081123244929798, 0.275, 'x[6] <= -0.047\nsquared_error = 4.0\nsamples = 2\nvalue = 247.0'),
#  Text(0.8049921996879875, 0.225, 'squared_error = 0.0\nsamples = 1\nvalue = 245.0'),
#  Text(0.8112324492979719, 0.225, 'squared_error = 0.0\nsamples = 1\nvalue = 249.0'),
#  Text(0.8143525741029641, 0.275, 'squared_error = 0.0\nsamples = 1\nvalue = 259.0'),
#  Text(0.8205928237129485, 0.375, 'x[0] <= 0.024\nsquared_error = 16.0\nsamples = 2\nvalue = 269.0'),
#  Text(0.8174726989079563, 0.325, 'squared_error = 0.0\nsamples = 1\nvalue = 265.0'),
#  Text(0.8237129485179407, 0.325, 'squared_error = 0.0\nsamples = 1\nvalue = 273.0'),
#  Text(0.8205928237129485, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 212.0'),
#  Text(0.8237129485179407, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 198.0'),
#  Text(0.8463338533541341, 0.575, 'x[3] <= 0.061\nsquared_error = 1507.076\nsamples = 12\nvalue = 181.583'),
#  Text(0.8377535101404057, 0.525, 'x[6] <= -0.031\nsquared_error = 925.25\nsamples = 10\nvalue = 169.5'),
#  Text(0.8299531981279251, 0.475, 'x[2] <= 0.008\nsquared_error = 62.889\nsamples = 3\nvalue = 141.667'),
#  Text(0.8268330733229329, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 131.0'),
#  Text(0.8330733229329174, 0.425, 'x[0] <= 0.064\nsquared_error = 9.0\nsamples = 2\nvalue = 147.0'),
#  Text(0.8299531981279251, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 150.0'),
#  Text(0.8361934477379095, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 144.0'),
#  Text(0.8455538221528861, 0.475, 'x[7] <= -0.021\nsquared_error = 820.531\nsamples = 7\nvalue = 181.429'),
#  Text(0.8424336973478939, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 134.0'),
#  Text(0.8486739469578783, 0.425, 'x[3] <= 0.051\nsquared_error = 519.889\nsamples = 6\nvalue = 189.333'),
#  Text(0.8424336973478939, 0.375, 'x[2] <= 0.012\nsquared_error = 485.688\nsamples = 4\nvalue = 198.75'),
#  Text(0.8393135725429017, 0.325, 'x[6] <= 0.025\nsquared_error = 156.222\nsamples = 3\nvalue = 187.667'),
#  Text(0.8361934477379095, 0.275, 'x[2] <= -0.004\nsquared_error = 0.25\nsamples = 2\nvalue = 196.5'),
#  Text(0.8330733229329174, 0.225, 'squared_error = 0.0\nsamples = 1\nvalue = 197.0'),
#  Text(0.8393135725429017, 0.225, 'squared_error = 0.0\nsamples = 1\nvalue = 196.0'),
#  Text(0.8424336973478939, 0.275, 'squared_error = 0.0\nsamples = 1\nvalue = 170.0'),
#  Text(0.8455538221528861, 0.325, 'squared_error = 0.0\nsamples = 1\nvalue = 232.0'),
#  Text(0.8549141965678627, 0.375, 'x[0] <= 0.051\nsquared_error = 56.25\nsamples = 2\nvalue = 170.5'),
#  Text(0.8517940717628705, 0.325, 'squared_error = 0.0\nsamples = 1\nvalue = 178.0'),
#  Text(0.858034321372855, 0.325, 'squared_error = 0.0\nsamples = 1\nvalue = 163.0'),
#  Text(0.8549141965678627, 0.525, 'x[8] <= 0.066\nsquared_error = 36.0\nsamples = 2\nvalue = 242.0'),
#  Text(0.8517940717628705, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 248.0'),
#  Text(0.858034321372855, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 236.0'),
#  Text(0.8795826833073322, 0.825, 'x[2] <= -0.026\nsquared_error = 2663.056\nsamples = 24\nvalue = 223.667'),
#  Text(0.8634945397815913, 0.775, 'x[7] <= 0.046\nsquared_error = 811.188\nsamples = 4\nvalue = 167.75'),
#  Text(0.8603744149765991, 0.725, 'x[0] <= 0.065\nsquared_error = 68.222\nsamples = 3\nvalue = 183.667'),
#  Text(0.8572542901716068, 0.675, 'x[0] <= 0.042\nsquared_error = 0.25\nsamples = 2\nvalue = 189.5'),
#  Text(0.8541341653666147, 0.625, 'squared_error = 0.0\nsamples = 1\nvalue = 190.0'),
#  Text(0.8603744149765991, 0.625, 'squared_error = 0.0\nsamples = 1\nvalue = 189.0'),
#  Text(0.8634945397815913, 0.675, 'squared_error = 0.0\nsamples = 1\nvalue = 172.0'),
#  Text(0.8666146645865834, 0.725, 'squared_error = 0.0\nsamples = 1\nvalue = 120.0'),
#  Text(0.8956708268330733, 0.775, 'x[9] <= 0.113\nsquared_error = 2283.028\nsamples = 20\nvalue = 234.85'),
#  Text(0.8818252730109204, 0.725, 'x[9] <= 0.071\nsquared_error = 2008.817\nsamples = 17\nvalue = 225.353'),
#  Text(0.8697347893915757, 0.675, 'x[3] <= -0.04\nsquared_error = 709.801\nsamples = 14\nvalue = 242.357'),
#  Text(0.8666146645865834, 0.625, 'squared_error = 0.0\nsamples = 1\nvalue = 192.0'),
#  Text(0.8728549141965679, 0.625, 'x[0] <= 0.005\nsquared_error = 554.331\nsamples = 13\nvalue = 246.231'),
#  Text(0.8642745709828393, 0.575, 'x[6] <= -0.018\nsquared_error = 38.222\nsamples = 3\nvalue = 266.667'),
#  Text(0.8611544461778471, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 258.0'),
#  Text(0.8673946957878315, 0.525, 'x[5] <= 0.058\nsquared_error = 1.0\nsamples = 2\nvalue = 271.0'),
#  Text(0.8642745709828393, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 270.0'),
#  Text(0.8705148205928237, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 272.0'),
#  Text(0.8814352574102964, 0.575, 'x[8] <= 0.037\nsquared_error = 546.29\nsamples = 10\nvalue = 240.1'),
#  Text(0.8783151326053042, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 191.0'),
#  Text(0.8845553822152886, 0.525, 'x[6] <= 0.03\nsquared_error = 309.358\nsamples = 9\nvalue = 245.556'),
#  Text(0.8767550702028081, 0.475, 'x[4] <= 0.004\nsquared_error = 99.551\nsamples = 7\nvalue = 237.857'),
#  Text(0.8705148205928237, 0.425, 'x[8] <= 0.06\nsquared_error = 36.0\nsamples = 2\nvalue = 226.0'),
#  Text(0.8673946957878315, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 232.0'),
#  Text(0.8736349453978159, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 220.0'),
#  Text(0.8829953198127926, 0.425, 'x[6] <= -0.073\nsquared_error = 46.24\nsamples = 5\nvalue = 242.6'),
#  Text(0.8798751950078003, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 230.0'),
#  Text(0.8861154446177847, 0.375, 'x[4] <= 0.067\nsquared_error = 8.188\nsamples = 4\nvalue = 245.75'),
#  Text(0.8829953198127926, 0.325, 'x[4] <= 0.03\nsquared_error = 0.889\nsamples = 3\nvalue = 247.333'),
#  Text(0.8798751950078003, 0.275, 'squared_error = 0.0\nsamples = 1\nvalue = 246.0'),
#  Text(0.8861154446177847, 0.275, 'squared_error = 0.0\nsamples = 2\nvalue = 248.0'),
#  Text(0.8892355694227769, 0.325, 'squared_error = 0.0\nsamples = 1\nvalue = 241.0'),
#  Text(0.8923556942277691, 0.475, 'x[6] <= 0.058\nsquared_error = 110.25\nsamples = 2\nvalue = 272.5'),
#  Text(0.8892355694227769, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 283.0'),
#  Text(0.8954758190327613, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 262.0'),
#  Text(0.8939157566302652, 0.675, 'x[0] <= -0.0\nsquared_error = 424.667\nsamples = 3\nvalue = 146.0'),
#  Text(0.890795631825273, 0.625, 'x[4] <= 0.051\nsquared_error = 90.25\nsamples = 2\nvalue = 132.5'),
#  Text(0.8876755070202809, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 123.0'),
#  Text(0.8939157566302652, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 142.0'),
#  Text(0.8970358814352574, 0.625, 'squared_error = 0.0\nsamples = 1\nvalue = 173.0'),
#  Text(0.9095163806552262, 0.725, 'x[5] <= 0.044\nsquared_error = 429.556\nsamples = 3\nvalue = 288.667'),
#  Text(0.906396255850234, 0.675, 'x[6] <= -0.038\nsquared_error = 42.25\nsamples = 2\nvalue = 274.5'),
#  Text(0.9032761310452418, 0.625, 'squared_error = 0.0\nsamples = 1\nvalue = 281.0'),
#  Text(0.9095163806552262, 0.625, 'squared_error = 0.0\nsamples = 1\nvalue = 268.0'),
#  Text(0.9126365054602185, 0.675, 'squared_error = 0.0\nsamples = 1\nvalue = 317.0'),
#  Text(0.9574882995319812, 0.875, 'x[4] <= 0.106\nsquared_error = 2964.566\nsamples = 28\nvalue = 258.071'),
#  Text(0.9543681747269891, 0.825, 'x[5] <= -0.061\nsquared_error = 2352.719\nsamples = 27\nvalue = 263.148'),
#  Text(0.9512480499219969, 0.775, 'squared_error = 0.0\nsamples = 1\nvalue = 132.0'),
#  Text(0.9574882995319812, 0.775, 'x[5] <= 0.025\nsquared_error = 1756.232\nsamples = 26\nvalue = 268.192'),
#  Text(0.9321372854914196, 0.725, 'x[8] <= 0.031\nsquared_error = 1105.734\nsamples = 16\nvalue = 287.125'),
#  Text(0.9188767550702028, 0.675, 'x[1] <= 0.003\nsquared_error = 34.667\nsamples = 3\nvalue = 338.0'),
#  Text(0.9157566302652106, 0.625, 'squared_error = 0.0\nsamples = 1\nvalue = 346.0'),
#  Text(0.921996879875195, 0.625, 'x[3] <= 0.051\nsquared_error = 4.0\nsamples = 2\nvalue = 334.0'),
#  Text(0.9188767550702028, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 332.0'),
#  Text(0.9251170046801872, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 336.0'),
#  Text(0.9453978159126365, 0.675, 'x[4] <= 0.032\nsquared_error = 617.775\nsamples = 13\nvalue = 275.385'),
#  Text(0.9375975039001561, 0.625, 'x[4] <= 0.02\nsquared_error = 446.05\nsamples = 10\nvalue = 266.5'),
#  Text(0.9313572542901716, 0.575, 'x[0] <= 0.056\nsquared_error = 157.25\nsamples = 8\nvalue = 275.0'),
#  Text(0.9282371294851794, 0.525, 'x[8] <= 0.044\nsquared_error = 51.714\nsamples = 7\nvalue = 271.0'),
#  Text(0.9204368174726989, 0.475, 'x[5] <= -0.014\nsquared_error = 4.0\nsamples = 2\nvalue = 261.0'),
#  Text(0.9173166926677067, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 263.0'),
#  Text(0.9235569422776911, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 259.0'),
#  Text(0.9360374414976599, 0.475, 'x[6] <= -0.053\nsquared_error = 14.8\nsamples = 5\nvalue = 275.0'),
#  Text(0.9297971918876755, 0.425, 'x[0] <= 0.013\nsquared_error = 1.0\nsamples = 2\nvalue = 271.0'),
#  Text(0.9266770670826833, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 272.0'),
#  Text(0.9329173166926678, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 270.0'),
#  Text(0.9422776911076443, 0.425, 'x[2] <= 0.065\nsquared_error = 6.222\nsamples = 3\nvalue = 277.667'),
#  Text(0.9391575663026521, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 281.0'),
#  Text(0.9453978159126365, 0.375, 'x[3] <= 0.027\nsquared_error = 1.0\nsamples = 2\nvalue = 276.0'),
#  Text(0.9422776911076443, 0.325, 'squared_error = 0.0\nsamples = 1\nvalue = 275.0'),
#  Text(0.9485179407176287, 0.325, 'squared_error = 0.0\nsamples = 1\nvalue = 277.0'),
#  Text(0.9344773790951638, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 303.0'),
#  Text(0.9438377535101404, 0.575, 'x[5] <= -0.023\nsquared_error = 156.25\nsamples = 2\nvalue = 232.5'),
#  Text(0.9407176287051482, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 245.0'),
#  Text(0.9469578783151326, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 220.0'),
#  Text(0.953198127925117, 0.625, 'x[6] <= -0.021\nsquared_error = 50.0\nsamples = 3\nvalue = 305.0'),
#  Text(0.9500780031201248, 0.575, 'squared_error = 0.0\nsamples = 2\nvalue = 310.0'),
#  Text(0.9563182527301092, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 295.0'),
#  Text(0.982839313572543, 0.725, 'x[9] <= 0.051\nsquared_error = 1305.89\nsamples = 10\nvalue = 237.9'),
#  Text(0.9719188767550702, 0.675, 'x[9] <= 0.04\nsquared_error = 660.98\nsamples = 7\nvalue = 220.143'),
#  Text(0.9656786271450858, 0.625, 'x[2] <= 0.066\nsquared_error = 185.25\nsamples = 4\nvalue = 235.5'),
#  Text(0.9625585023400937, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 215.0'),
#  Text(0.968798751950078, 0.575, 'x[5] <= 0.07\nsquared_error = 60.222\nsamples = 3\nvalue = 242.333'),
#  Text(0.9656786271450858, 0.525, 'x[9] <= 0.011\nsquared_error = 20.25\nsamples = 2\nvalue = 237.5'),
#  Text(0.9625585023400937, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 233.0'),
#  Text(0.968798751950078, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 242.0'),
#  Text(0.9719188767550702, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 252.0'),
#  Text(0.9781591263650546, 0.625, 'x[3] <= 0.003\nsquared_error = 561.556\nsamples = 3\nvalue = 199.667'),
#  Text(0.9750390015600624, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 233.0'),
#  Text(0.9812792511700468, 0.575, 'x[0] <= 0.011\nsquared_error = 9.0\nsamples = 2\nvalue = 183.0'),
#  Text(0.9781591263650546, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 186.0'),
#  Text(0.984399375975039, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 180.0'),
#  Text(0.9937597503900156, 0.675, 'x[7] <= 0.127\nsquared_error = 358.222\nsamples = 3\nvalue = 279.333'),
#  Text(0.9906396255850234, 0.625, 'x[5] <= 0.05\nsquared_error = 4.0\nsamples = 2\nvalue = 266.0'),
#  Text(0.9875195007800313, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 264.0'),
#  Text(0.9937597503900156, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 268.0'),
#  Text(0.9968798751950078, 0.625, 'squared_error = 0.0\nsamples = 1\nvalue = 306.0'),
#  Text(0.9606084243369735, 0.825, 'squared_error = 0.0\nsamples = 1\nvalue = 121.0')]

# %%
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error
y_pred1= regressor.predict(X_test)
print(r2_score(y_test,y_pred1))

print(mean_absolute_error(y_test,y_pred1))
print(mean_squared_error(y_test,y_pred1))
# Out:
# -0.20476329287221517
# 68.7593984962406
# 7623.345864661655

# %% [markdown]
# ## Hyperparameter Tuning

# %%
param={
    'criterion':['squared_error','friedman_mse','absolute_error'],
    'splitter':['best','random'],
    'max_depth':[1,2,3,4,5,10,15,20,25],
    'max_features':['auto','sqrt','log2']
}

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
param
# Out:
# {'criterion': ['squared_error', 'friedman_mse', 'absolute_error'],
#  'splitter': ['best', 'random'],
#  'max_depth': [1, 2, 3, 4, 5, 10, 15, 20, 25],
#  'max_features': ['auto', 'sqrt', 'log2']}

# %%
from sklearn.model_selection import GridSearchCV

# %%
regressor=DecisionTreeRegressor()

# %%
grid=GridSearchCV(regressor,param_grid=param,cv=5,scoring='neg_mean_squared_error')

# %%
import warnings
warnings.filterwarnings('ignore')
grid.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeRegressor(),
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error'],
#                          'max_depth': [1, 2, 3, 4, 5, 10, 15, 20, 25],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              scoring='neg_mean_squared_error')

# %%
grid.best_params_
# Out:
# {'criterion': 'friedman_mse',
#  'max_depth': 3,
#  'max_features': 'sqrt',
#  'splitter': 'best'}

# %%
## predictions
y_pred=grid.predict(X_test)

# %%
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

# %%
print(r2_score(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
print(mean_squared_error(y_test,y_pred))
# Out:
# 0.3847460672400853
# 49.62945205823924
# 3893.124526428941

# %%
selectedmodel=DecisionTreeRegressor(criterion='friedman_mse',max_depth=4,max_features='log2',splitter='random')

# %%
selectedmodel.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor(criterion='friedman_mse', max_depth=4,
#                       max_features='log2', splitter='random')

# %%
##Visualize the Decision Tree
import matplotlib.pyplot as plt
from sklearn import tree
plt.figure(figsize=(15,10))
tree.plot_tree(selectedmodel,filled=True)
# Out:
# [Text(0.5446428571428571, 0.9, 'x[8] <= -0.421\nfriedman_mse = 5757.456\nsamples = 309\nvalue = 152.738'),
#  Text(0.2857142857142857, 0.7, 'x[6] <= 1.314\nfriedman_mse = 2781.398\nsamples = 117\nvalue = 105.889'),
#  Text(0.4151785714285714, 0.8, 'True  '),
#  Text(0.14285714285714285, 0.5, 'x[7] <= -0.314\nfriedman_mse = 3155.319\nsamples = 97\nvalue = 110.021'),
#  Text(0.07142857142857142, 0.3, 'x[4] <= -1.426\nfriedman_mse = 2597.249\nsamples = 60\nvalue = 99.867'),
#  Text(0.03571428571428571, 0.1, 'friedman_mse = 2139.779\nsamples = 17\nvalue = 94.529'),
#  Text(0.10714285714285714, 0.1, 'friedman_mse = 2762.395\nsamples = 43\nvalue = 101.977'),
#  Text(0.21428571428571427, 0.3, 'x[1] <= 1.033\nfriedman_mse = 3621.98\nsamples = 37\nvalue = 126.486'),
#  Text(0.17857142857142858, 0.1, 'friedman_mse = 3689.69\nsamples = 19\nvalue = 138.684'),
#  Text(0.25, 0.1, 'friedman_mse = 3227.682\nsamples = 18\nvalue = 113.611'),
#  Text(0.42857142857142855, 0.5, 'x[0] <= -0.202\nfriedman_mse = 483.528\nsamples = 20\nvalue = 85.85'),
#  Text(0.35714285714285715, 0.3, 'x[7] <= -1.0\nfriedman_mse = 699.96\nsamples = 10\nvalue = 81.2'),
#  Text(0.32142857142857145, 0.1, 'friedman_mse = 315.0\nsamples = 4\nvalue = 67.0'),
#  Text(0.39285714285714285, 0.1, 'friedman_mse = 732.556\nsamples = 6\nvalue = 90.667'),
#  Text(0.5, 0.3, 'x[6] <= 1.726\nfriedman_mse = 223.85\nsamples = 10\nvalue = 90.5'),
#  Text(0.4642857142857143, 0.1, 'friedman_mse = 181.714\nsamples = 7\nvalue = 89.0'),
#  Text(0.5357142857142857, 0.1, 'friedman_mse = 304.667\nsamples = 3\nvalue = 94.0'),
#  Text(0.8035714285714286, 0.7, 'x[9] <= 2.667\nfriedman_mse = 5418.496\nsamples = 192\nvalue = 181.286'),
#  Text(0.6741071428571428, 0.8, '  False'),
#  Text(0.7142857142857143, 0.5, 'x[9] <= 1.192\nfriedman_mse = 5268.032\nsamples = 188\nvalue = 179.011'),
#  Text(0.6428571428571429, 0.3, 'x[3] <= -0.189\nfriedman_mse = 4936.684\nsamples = 161\nvalue = 173.304'),
#  Text(0.6071428571428571, 0.1, 'friedman_mse = 4965.04\nsamples = 60\nvalue = 151.4'),
#  Text(0.6785714285714286, 0.1, 'friedman_mse = 4465.484\nsamples = 101\nvalue = 186.317'),
#  Text(0.7857142857142857, 0.3, 'x[8] <= 0.593\nfriedman_mse = 5891.888\nsamples = 27\nvalue = 213.037'),
#  Text(0.75, 0.1, 'friedman_mse = 6903.849\nsamples = 15\nvalue = 195.533'),
#  Text(0.8214285714285714, 0.1, 'friedman_mse = 3765.243\nsamples = 12\nvalue = 234.917'),
#  Text(0.8928571428571429, 0.5, 'x[5] <= 0.386\nfriedman_mse = 805.688\nsamples = 4\nvalue = 288.25'),
#  Text(0.8571428571428571, 0.3, 'friedman_mse = 0.0\nsamples = 1\nvalue = 245.0'),
#  Text(0.9285714285714286, 0.3, 'x[0] <= 0.899\nfriedman_mse = 242.889\nsamples = 3\nvalue = 302.667'),
#  Text(0.8928571428571429, 0.1, 'friedman_mse = 0.0\nsamples = 1\nvalue = 317.0'),
#  Text(0.9642857142857143, 0.1, 'friedman_mse = 210.25\nsamples = 2\nvalue = 295.5')]
