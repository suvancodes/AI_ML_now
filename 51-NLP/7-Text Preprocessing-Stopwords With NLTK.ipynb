# %%
## Speech Of DR APJ Abdul Kalam
paragraph = """I have three visions for India. In 3000 years of our history, people from all over 
               the world have come and invaded us, captured our lands, conquered our minds. 
               From Alexander onwards, the Greeks, the Turks, the Moguls, the Portuguese, the British,
               the French, the Dutch, all of them came and looted us, took over what was ours. 
               Yet we have not done this to any other nation. We have not conquered anyone. 
               We have not grabbed their land, their culture, 
               their history and tried to enforce our way of life on them. 
               Why? Because we respect the freedom of others.That is why my 
               first vision is that of freedom. I believe that India got its first vision of 
               this in 1857, when we started the War of Independence. It"""

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

import nltk
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /Users/apple/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /Users/apple/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
words = word_tokenize(paragraph)

# %%
stop_words = set(stopwords.words('english'))
print(stop_words)
# Out:
# {"you've", 'did', "we've", 'why', "weren't", "it's", 'now', 'on', 'them', 'between', 'are', 'hadn', "i'd", 'until', 'very', 'itself', 'what', "hasn't", 'ain', "she'll", "he'd", 'was', 'be', 'from', 're', 'other', 'and', "they've", "we'll", 'which', 'above', 'below', 'ourselves', 'through', "doesn't", 'needn', 'such', 'couldn', 'wouldn', 'does', 'because', "you'd", "needn't", 'were', "you're", 'against', 'doing', "mightn't", 'both', 'd', 'doesn', 'after', 'with', "we'd", 'then', 'her', 'been', 'don', 'out', 'our', 'at', 'themselves', 'when', 'just', 'who', 'only', 'herself', 'shan', "shouldn't", 'have', 'they', 'too', 'weren', 'she', 'any', 'there', 'not', 'mightn', "you'll", "it'd", 'as', 'in', 'each', 'where', 'has', 'during', 'will', 's', 'to', "they're", "they'd", 'same', 'hers', 'over', 'hasn', 'your', "couldn't", 'further', 'here', 'm', 'of', 'up', 'aren', "hadn't", "we're", 'how', 'into', 'by', 'whom', 'this', 'the', 'o', 'he', 'an', 'shouldn', 'more', "they'll", 'or', 'll', "she'd", 'its', 'isn', "wasn't", "i've", 'yourself', 'wasn', "haven't", 'while', "should've", 'if', 'having', "it'll", 'him', 'won', "won't", 'nor', "aren't", 'is', 'ours', 'y', 'once', "didn't", 'off', 'yourselves', 'that', 'theirs', 'all', 'it', 'few', 'i', 'me', 'do', 'their', 'my', 'no', 'haven', "i'm", 'before', 'himself', 'had', 'most', 'you', 'those', "she's", 'yours', "he'll", 'can', 'for', "isn't", 've', 'didn', "mustn't", "wouldn't", 'so', 'than', "he's", 'myself', "that'll", 'under', 'again', 'own', 't', 'but', "don't", 'his', 'being', 'am', 'about', 'down', "i'll", 'some', 'these', "shan't", 'we', 'ma', 'mustn', 'should', 'a'}

# %%
filtered_words = [word for word in words if word.lower() not in stop_words]
print(filtered_words)
# Out:
# ['three', 'visions', 'India', '.', '3000', 'years', 'history', ',', 'people', 'world', 'come', 'invaded', 'us', ',', 'captured', 'lands', ',', 'conquered', 'minds', '.', 'Alexander', 'onwards', ',', 'Greeks', ',', 'Turks', ',', 'Moguls', ',', 'Portuguese', ',', 'British', ',', 'French', ',', 'Dutch', ',', 'came', 'looted', 'us', ',', 'took', '.', 'Yet', 'done', 'nation', '.', 'conquered', 'anyone', '.', 'grabbed', 'land', ',', 'culture', ',', 'history', 'tried', 'enforce', 'way', 'life', '.', '?', 'respect', 'freedom', 'others.That', 'first', 'vision', 'freedom', '.', 'believe', 'India', 'got', 'first', 'vision', '1857', ',', 'started', 'War', 'Independence', '.']

# %%
words
# Out:
# ['I',
#  'have',
#  'three',
#  'visions',
#  'for',
#  'India',
#  '.',
#  'In',
#  '3000',
#  'years',
#  'of',
#  'our',
#  'history',
#  ',',
#  'people',
#  'from',
#  'all',
#  'over',
#  'the',
#  'world',
#  'have',
#  'come',
#  'and',
#  'invaded',
#  'us',
#  ',',
#  'captured',
#  'our',
#  'lands',
#  ',',
#  'conquered',
#  'our',
#  'minds',
#  '.',
#  'From',
#  'Alexander',
#  'onwards',
#  ',',
#  'the',
#  'Greeks',
#  ',',
#  'the',
#  'Turks',
#  ',',
#  'the',
#  'Moguls',
#  ',',
#  'the',
#  'Portuguese',
#  ',',
#  'the',
#  'British',
#  ',',
#  'the',
#  'French',
#  ',',
#  'the',
#  'Dutch',
#  ',',
#  'all',
#  'of',
#  'them',
#  'came',
#  'and',
#  'looted',
#  'us',
#  ',',
#  'took',
#  'over',
#  'what',
#  'was',
#  'ours',
#  '.',
#  'Yet',
#  'we',
#  'have',
#  'not',
#  'done',
#  'this',
#  'to',
#  'any',
#  'other',
#  'nation',
#  '.',
#  'We',
#  'have',
#  'not',
#  'conquered',
#  'anyone',
#  '.',
#  'We',
#  'have',
#  'not',
#  'grabbed',
#  'their',
#  'land',
#  ',',
#  'their',
#  'culture',
#  ',',
#  'their',
#  'history',
#  'and',
#  'tried',
#  'to',
#  'enforce',
#  'our',
#  'way',
#  'of',
#  'life',
#  'on',
#  'them',
#  '.',
#  'Why',
#  '?',
#  'Because',
#  'we',
#  'respect',
#  'the',
#  'freedom',
#  'of',
#  'others.That',
#  'is',
#  'why',
#  'my',
#  'first',
#  'vision',
#  'is',
#  'that',
#  'of',
#  'freedom',
#  '.',
#  'I',
#  'believe',
#  'that',
#  'India',
#  'got',
#  'its',
#  'first',
#  'vision',
#  'of',
#  'this',
#  'in',
#  '1857',
#  ',',
#  'when',
#  'we',
#  'started',
#  'the',
#  'War',
#  'of',
#  'Independence',
#  '.',
#  'It']
