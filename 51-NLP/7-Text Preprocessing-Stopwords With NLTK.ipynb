# %%
## Speech Of DR APJ Abdul Kalam
paragraph = """I have three visions for India. In 3000 years of our history, people from all over 
               the world have come and invaded us, captured our lands, conquered our minds. 
               From Alexander onwards, the Greeks, the Turks, the Moguls, the Portuguese, the British,
               the French, the Dutch, all of them came and looted us, took over what was ours. 
               Yet we have not done this to any other nation. We have not conquered anyone. 
               We have not grabbed their land, their culture, 
               their history and tried to enforce our way of life on them. 
               Why? Because we respect the freedom of others.That is why my 
               first vision is that of freedom. I believe that India got its first vision of 
               this in 1857, when we started the War of Independence. It"""

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

import nltk
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /Users/apple/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /Users/apple/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
words = word_tokenize(paragraph)

# %%
stop_words = set(stopwords.words('english'))
print(stop_words)
# Out:
# {'all', 'mightn', "i've", 'were', 'their', 'she', 'don', 's', 'not', 'only', "he'd", 'now', 'same', 'there', 'are', 'has', 'i', "haven't", 'doing', "doesn't", 'ours', "it's", "we've", 're', "aren't", 'other', "wouldn't", "he'll", 'itself', "they've", 'as', 'what', 'll', 'too', 'to', 'once', 'hadn', "she's", 'out', 'why', "you'd", "wasn't", 'above', "we're", "you're", 'mustn', "i'm", 'ma', 'needn', 'didn', 'them', 'is', 'did', "mustn't", 'while', 'y', "couldn't", 'no', 'will', 'hers', "you've", 'which', 'by', "shouldn't", 'theirs', 'but', 'further', 'on', 'yourself', 'him', 'and', 'isn', 'himself', 'am', "we'd", 'how', 'd', 'its', 'most', 'off', 'yourselves', 'then', 'at', 'between', 'haven', 'or', 've', 'o', "mightn't", 'our', 'he', "shan't", 'both', 'whom', 'does', 'under', 'shan', "they're", "it'd", "they'd", 'for', 'had', 'his', 'before', 'until', 'ain', 'an', 'up', "isn't", 'weren', "hasn't", "it'll", "needn't", 'this', 'from', 'very', "won't", 'than', 'won', 'these', 'her', 'm', 'shouldn', 'your', 'a', 'been', 'can', 'the', 'we', 'themselves', 'just', 'couldn', 'myself', 'ourselves', 'during', 'any', 'with', 'aren', "i'd", 'they', 'over', 'if', "he's", 'have', 'nor', 'you', 'be', 'more', 'again', "she'll", 't', 'own', 'yours', 'down', "we'll", "don't", 'who', "didn't", 'being', 'my', 'because', 'through', 'herself', 'about', 'when', 'against', 'after', 'those', "should've", "that'll", 'here', "weren't", 'was', 'that', 'such', "you'll", 'where', 'should', 'me', 'do', 'few', 'hasn', 'in', 'having', "she'd", 'wasn', 'it', 'of', 'into', "hadn't", "i'll", 'so', 'below', 'doesn', 'some', 'each', 'wouldn', "they'll"}

# %%
filtered_words = [word for word in words if word.lower() not in stop_words]
print(filtered_words)
# Out:
# ['three', 'visions', 'India', '.', '3000', 'years', 'history', ',', 'people', 'world', 'come', 'invaded', 'us', ',', 'captured', 'lands', ',', 'conquered', 'minds', '.', 'Alexander', 'onwards', ',', 'Greeks', ',', 'Turks', ',', 'Moguls', ',', 'Portuguese', ',', 'British', ',', 'French', ',', 'Dutch', ',', 'came', 'looted', 'us', ',', 'took', '.', 'Yet', 'done', 'nation', '.', 'conquered', 'anyone', '.', 'grabbed', 'land', ',', 'culture', ',', 'history', 'tried', 'enforce', 'way', 'life', '.', '?', 'respect', 'freedom', 'others.That', 'first', 'vision', 'freedom', '.', 'believe', 'India', 'got', 'first', 'vision', '1857', ',', 'started', 'War', 'Independence', '.']

# %%
words
# Out:
# ['I',
#  'have',
#  'three',
#  'visions',
#  'for',
#  'India',
#  '.',
#  'In',
#  '3000',
#  'years',
#  'of',
#  'our',
#  'history',
#  ',',
#  'people',
#  'from',
#  'all',
#  'over',
#  'the',
#  'world',
#  'have',
#  'come',
#  'and',
#  'invaded',
#  'us',
#  ',',
#  'captured',
#  'our',
#  'lands',
#  ',',
#  'conquered',
#  'our',
#  'minds',
#  '.',
#  'From',
#  'Alexander',
#  'onwards',
#  ',',
#  'the',
#  'Greeks',
#  ',',
#  'the',
#  'Turks',
#  ',',
#  'the',
#  'Moguls',
#  ',',
#  'the',
#  'Portuguese',
#  ',',
#  'the',
#  'British',
#  ',',
#  'the',
#  'French',
#  ',',
#  'the',
#  'Dutch',
#  ',',
#  'all',
#  'of',
#  'them',
#  'came',
#  'and',
#  'looted',
#  'us',
#  ',',
#  'took',
#  'over',
#  'what',
#  'was',
#  'ours',
#  '.',
#  'Yet',
#  'we',
#  'have',
#  'not',
#  'done',
#  'this',
#  'to',
#  'any',
#  'other',
#  'nation',
#  '.',
#  'We',
#  'have',
#  'not',
#  'conquered',
#  'anyone',
#  '.',
#  'We',
#  'have',
#  'not',
#  'grabbed',
#  'their',
#  'land',
#  ',',
#  'their',
#  'culture',
#  ',',
#  'their',
#  'history',
#  'and',
#  'tried',
#  'to',
#  'enforce',
#  'our',
#  'way',
#  'of',
#  'life',
#  'on',
#  'them',
#  '.',
#  'Why',
#  '?',
#  'Because',
#  'we',
#  'respect',
#  'the',
#  'freedom',
#  'of',
#  'others.That',
#  'is',
#  'why',
#  'my',
#  'first',
#  'vision',
#  'is',
#  'that',
#  'of',
#  'freedom',
#  '.',
#  'I',
#  'believe',
#  'that',
#  'India',
#  'got',
#  'its',
#  'first',
#  'vision',
#  'of',
#  'this',
#  'in',
#  '1857',
#  ',',
#  'when',
#  'we',
#  'started',
#  'the',
#  'War',
#  'of',
#  'Independence',
#  '.',
#  'It']

# %%
paragraph = """I have three visions for India. In 3000 years of our history, people from all over 
               the world have come and invaded us, captured our lands, conquered our minds. 
               From Alexander onwards, the Greeks, the Turks, the Moguls, the Portuguese, the British,
               the French, the Dutch, all of them came and looted us, took over what was ours. 
               Yet we have not done this to any other nation. We have not conquered anyone. 
               We have not grabbed their land, their culture, 
               their history and tried to enforce our way of life on them. 
               Why? Because we respect the freedom of others.That is why my 
               first vision is that of freedom. I believe that India got its first vision of 
               this in 1857, when we started the War of Independence. It"""

# %%
from nltk.tokenize import sent_tokenize
sentences = sent_tokenize(paragraph)
print(len(sentences))
# Out:
# 10

# %%
all_filtered_words = []

for sentence in sentences:
    words = word_tokenize(sentence)
    filtered_words = [w for w in words if w.lower() not in stop_words]
    all_filtered_words.append(filtered_words)

print(all_filtered_words)
# Out:
# [['three', 'visions', 'India', '.'], ['3000', 'years', 'history', ',', 'people', 'world', 'come', 'invaded', 'us', ',', 'captured', 'lands', ',', 'conquered', 'minds', '.'], ['Alexander', 'onwards', ',', 'Greeks', ',', 'Turks', ',', 'Moguls', ',', 'Portuguese', ',', 'British', ',', 'French', ',', 'Dutch', ',', 'came', 'looted', 'us', ',', 'took', '.'], ['Yet', 'done', 'nation', '.'], ['conquered', 'anyone', '.'], ['grabbed', 'land', ',', 'culture', ',', 'history', 'tried', 'enforce', 'way', 'life', '.'], ['?'], ['respect', 'freedom', 'others.That', 'first', 'vision', 'freedom', '.'], ['believe', 'India', 'got', 'first', 'vision', '1857', ',', 'started', 'War', 'Independence', '.'], []]

# %%
all_filtered_words
# Out:
# [['three', 'visions', 'India', '.'],
#  ['3000',
#   'years',
#   'history',
#   ',',
#   'people',
#   'world',
#   'come',
#   'invaded',
#   'us',
#   ',',
#   'captured',
#   'lands',
#   ',',
#   'conquered',
#   'minds',
#   '.'],
#  ['Alexander',
#   'onwards',
#   ',',
#   'Greeks',
#   ',',
#   'Turks',
#   ',',
#   'Moguls',
#   ',',
#   'Portuguese',
#   ',',
#   'British',
#   ',',
#   'French',
#   ',',
#   'Dutch',
#   ',',
#   'came',
#   'looted',
#   'us',
#   ',',
#   'took',
#   '.'],
#  ['Yet', 'done', 'nation', '.'],
#  ['conquered', 'anyone', '.'],
#  ['grabbed',
#   'land',
#   ',',
#   'culture',
#   ',',
#   'history',
#   'tried',
#   'enforce',
#   'way',
#   'life',
#   '.'],
#  ['?'],
#  ['respect', 'freedom', 'others.That', 'first', 'vision', 'freedom', '.'],
#  ['believe',
#   'India',
#   'got',
#   'first',
#   'vision',
#   '1857',
#   ',',
#   'started',
#   'War',
#   'Independence',
#   '.'],
#  []]

# %%
from nltk.stem import WordNetLemmatizer
nltk.download('wordnet')
lemmatizer = WordNetLemmatizer()
for word in all_filtered_words:
    for w in word:
        lemmatized_word = lemmatizer.lemmatize(w)
        print(f"Normal word: {w} | Lemmatized word: {lemmatized_word}")
# Out:
# Normal word: three | Lemmatized word: three
# Normal word: visions | Lemmatized word: vision
# Normal word: India | Lemmatized word: India
# Normal word: . | Lemmatized word: .
# Normal word: 3000 | Lemmatized word: 3000
# Normal word: years | Lemmatized word: year
# Normal word: history | Lemmatized word: history
# Normal word: , | Lemmatized word: ,
# Normal word: people | Lemmatized word: people
# Normal word: world | Lemmatized word: world
# Normal word: come | Lemmatized word: come
# Normal word: invaded | Lemmatized word: invaded
# Normal word: us | Lemmatized word: u
# Normal word: , | Lemmatized word: ,
# Normal word: captured | Lemmatized word: captured
# Normal word: lands | Lemmatized word: land
# Normal word: , | Lemmatized word: ,
# Normal word: conquered | Lemmatized word: conquered
# Normal word: minds | Lemmatized word: mind
# Normal word: . | Lemmatized word: .
# Normal word: Alexander | Lemmatized word: Alexander
# Normal word: onwards | Lemmatized word: onwards
# Normal word: , | Lemmatized word: ,
# Normal word: Greeks | Lemmatized word: Greeks
# Normal word: , | Lemmatized word: ,
# Normal word: Turks | Lemmatized word: Turks
# Normal word: , | Lemmatized word: ,
# Normal word: Moguls | Lemmatized word: Moguls
# Normal word: , | Lemmatized word: ,
# Normal word: Portuguese | Lemmatized word: Portuguese
# Normal word: , | Lemmatized word: ,
# Normal word: British | Lemmatized word: British
# Normal word: , | Lemmatized word: ,
# Normal word: French | Lemmatized word: French
# Normal word: , | Lemmatized word: ,
# Normal word: Dutch | Lemmatized word: Dutch
# Normal word: , | Lemmatized word: ,
# Normal word: came | Lemmatized word: came
# Normal word: looted | Lemmatized word: looted
# Normal word: us | Lemmatized word: u
# Normal word: , | Lemmatized word: ,
# Normal word: took | Lemmatized word: took
# Normal word: . | Lemmatized word: .
# Normal word: Yet | Lemmatized word: Yet
# Normal word: done | Lemmatized word: done
# Normal word: nation | Lemmatized word: nation
# Normal word: . | Lemmatized word: .
# Normal word: conquered | Lemmatized word: conquered
# Normal word: anyone | Lemmatized word: anyone
# Normal word: . | Lemmatized word: .
# Normal word: grabbed | Lemmatized word: grabbed
# Normal word: land | Lemmatized word: land
# Normal word: , | Lemmatized word: ,
# Normal word: culture | Lemmatized word: culture
# Normal word: , | Lemmatized word: ,
# Normal word: history | Lemmatized word: history
# Normal word: tried | Lemmatized word: tried
# Normal word: enforce | Lemmatized word: enforce
# Normal word: way | Lemmatized word: way
# Normal word: life | Lemmatized word: life
# Normal word: . | Lemmatized word: .
# Normal word: ? | Lemmatized word: ?
# Normal word: respect | Lemmatized word: respect
# Normal word: freedom | Lemmatized word: freedom
# Normal word: others.That | Lemmatized word: others.That
# Normal word: first | Lemmatized word: first
# Normal word: vision | Lemmatized word: vision
# Normal word: freedom | Lemmatized word: freedom
# Normal word: . | Lemmatized word: .
# Normal word: believe | Lemmatized word: believe
# Normal word: India | Lemmatized word: India
# Normal word: got | Lemmatized word: got
# Normal word: first | Lemmatized word: first
# Normal word: vision | Lemmatized word: vision
# Normal word: 1857 | Lemmatized word: 1857
# Normal word: , | Lemmatized word: ,
# Normal word: started | Lemmatized word: started
# Normal word: War | Lemmatized word: War
# Normal word: Independence | Lemmatized word: Independence
# Normal word: . | Lemmatized word: .
# [nltk_data] Downloading package wordnet to /Users/apple/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
paragraph
# Out:
# 'three vision India . 3000 year history , people world come invaded u , captured land , conquered mind . Alexander onwards , Greeks , Turks , Moguls , Portuguese , British , French , Dutch , came looted u , took . Yet done nation . conquered anyone . grabbed land , culture , history tried enforce way life . ? respect freedom others.That first vision freedom . believe India got first vision 1857 , started War Independence . '

# %%
lemmatized_paragraph
# Out:
# 'three vision India . 3000 year history , people world come invaded u , captured land , conquered mind . Alexander onwards , Greeks , Turks , Moguls , Portuguese , British , French , Dutch , came looted u , took . Yet done nation . conquered anyone . grabbed land , culture , history tried enforce way life . ? respect freedom others.That first vision freedom . believe India got first vision 1857 , started War Independence . '
